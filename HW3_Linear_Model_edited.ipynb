# %%
import pandas as pd
import ast

# %%
df = pd.read_csv('attribution_allocation_student_data.csv')
df.head(20)
# Out:
#     convert_TF       touch1    touch2       touch3    touch4 touch5  tier
# 0         True     referral  referral     referral     email    NaN     1
# 1         True     referral   display      display     email    NaN     1
# 2         True        email   display     referral       NaN    NaN     1
# 3         True     referral  referral        email       NaN    NaN     1
# 4         True       social  referral          NaN       NaN    NaN     1
# 5         True     referral  referral        email       NaN    NaN     1
# 6         True        email  referral     referral       NaN    NaN     1
# 7         True        email  referral     referral  referral    NaN     1
# 8         True     referral       NaN          NaN       NaN    NaN     1
# 9         True     referral  referral        email       NaN    NaN     1
# 10        True        email    social       social       NaN    NaN     1
# 11        True        email  referral        email       NaN    NaN     1
# 12        True        email       NaN          NaN       NaN    NaN     1
# 13        True  paid_search     email          NaN       NaN    NaN     1
# 14        True        email  referral          NaN       NaN    NaN     1
# 15        True  paid_search  referral        email     email    NaN     1
# 16        True        email  referral        email       NaN    NaN     1
# 17        True     referral  referral        email       NaN    NaN     1
# 18        True        email  referral  paid_search       NaN    NaN     1
# 19        True     referral     email          NaN       NaN    NaN     1

# %%
input_file = pd.read_csv('channel_spend_student_data.csv', skiprows=1, names = ['tier', 'spend'])
input_file
# Out:
#     tier                                              spend
# 0  tier1  {'email': 1000.0, 'social': 1000.0000000000001...
# 1  tier2  {'email': 2000.0, 'social': 2000.0, 'display':...
# 2  tier3  {'email': 3000.0, 'social': 3000.0, 'display':...

# %% [markdown]
# # calculate cost for each channel

# %%
input_file['spend']=input_file['spend'].apply(ast.literal_eval)

# %%
tier1_spend_dict = input_file.iloc[0,1]
tier2_spend_dict = input_file.iloc[1,1]
tier3_spend_dict = input_file.iloc[2,1]

# %%
tier1_spend = pd.DataFrame(list(tier1_spend_dict.items()),columns = ['channel','spend'])
tier2_spend = pd.DataFrame(list(tier2_spend_dict.items()),columns = ['channel','spend'])
tier3_spend = pd.DataFrame(list(tier3_spend_dict.items()),columns = ['channel','spend'])

# %%
tier1 = df[df['tier'] == 1]
tier2 = df[df['tier'] == 2]
tier3 = df[df['tier'] == 3]

# %% [markdown]
# # Linear Model

# %%
convert1 = tier1[tier1['convert_TF'] == True]
convert2 = tier2[tier2['convert_TF'] == True]
convert3 = tier3[tier3['convert_TF'] == True]
print(convert1)
print(convert2)
print(convert3)
# Out:
#        convert_TF    touch1    touch2          touch3  touch4    touch5  tier
# 0            True  referral  referral        referral   email       NaN     1
# 1            True  referral   display         display   email       NaN     1
# 2            True     email   display        referral     NaN       NaN     1
# 3            True  referral  referral           email     NaN       NaN     1
# 4            True    social  referral             NaN     NaN       NaN     1
# ...           ...       ...       ...             ...     ...       ...   ...
# 4304         True  referral  referral        referral     NaN       NaN     1
# 4305         True  referral  referral          social  social  referral     1
# 11333        True  referral  referral  organic_search     NaN       NaN     1
# 11334        True  referral  referral  organic_search     NaN       NaN     1
# 11347        True  referral  referral             NaN     NaN       NaN     1
#
# [2824 rows x 7 columns]
#        convert_TF          touch1    touch2          touch3    touch4 touch5  \
# 11354        True         display  referral        referral     email    NaN
# 11355        True        referral  referral           email       NaN    NaN
# 11356        True           email    social          social       NaN    NaN
# 11357        True          social     email             NaN       NaN    NaN
# 11358        True           email  referral           email       NaN    NaN
# ...           ...             ...       ...             ...       ...    ...
# 26941        True        referral     email             NaN       NaN    NaN
# 26942        True        referral  referral        referral       NaN    NaN
# 34041        True  organic_search  referral        referral       NaN    NaN
# 34042        True        referral  referral  organic_search       NaN    NaN
# 34055        True          direct  referral        referral  referral    NaN
#
#        tier
# 11354     2
# 11355     2
# 11356     2
# 11357     2
# 11358     2
# ...     ...
# 26941     2
# 26942     2
# 34041     2
# 34042     2
# 34055     2
#
# [4892 rows x 7 columns]
#        convert_TF          touch1    touch2       touch3 touch4 touch5  tier
# 34062        True        referral  referral     referral  email    NaN     3
# 34063        True           email     email       social    NaN    NaN     3
# 34064        True        referral  referral        email    NaN    NaN     3
# 34065        True           email  referral     referral    NaN    NaN     3
# 34066        True           email  referral     referral    NaN    NaN     3
# ...           ...             ...       ...          ...    ...    ...   ...
# 60648        True        referral  referral     referral    NaN    NaN     3
# 60649        True         display  referral          NaN    NaN    NaN     3
# 68103        True  organic_search  referral  paid_search    NaN    NaN     3
# 68104        True  organic_search   display          NaN    NaN    NaN     3
# 68117        True          direct       NaN          NaN    NaN    NaN     3
#
# [6063 rows x 7 columns]

# %%
convert1_combined = convert1.iloc[:,1:6]
convert1_combined
# Out:
#          touch1    touch2          touch3  touch4    touch5
# 0      referral  referral        referral   email       NaN
# 1      referral   display         display   email       NaN
# 2         email   display        referral     NaN       NaN
# 3      referral  referral           email     NaN       NaN
# 4        social  referral             NaN     NaN       NaN
# ...         ...       ...             ...     ...       ...
# 4304   referral  referral        referral     NaN       NaN
# 4305   referral  referral          social  social  referral
# 11333  referral  referral  organic_search     NaN       NaN
# 11334  referral  referral  organic_search     NaN       NaN
# 11347  referral  referral             NaN     NaN       NaN
#
# [2824 rows x 5 columns]

# %%
convert1_combined['combined']= convert1_combined.values.tolist()
convert1_combined.drop(convert1_combined.iloc[:, 0:5], inplace=True, axis=1)
convert1_combined
# Out:
#                                              combined
# 0          [referral, referral, referral, email, nan]
# 1            [referral, display, display, email, nan]
# 2                [email, display, referral, nan, nan]
# 3               [referral, referral, email, nan, nan]
# 4                   [social, referral, nan, nan, nan]
# ...                                               ...
# 4304         [referral, referral, referral, nan, nan]
# 4305   [referral, referral, social, social, referral]
# 11333  [referral, referral, organic_search, nan, nan]
# 11334  [referral, referral, organic_search, nan, nan]
# 11347             [referral, referral, nan, nan, nan]
#
# [2824 rows x 1 columns]

# %%
touch_list_convert1 = convert1_combined['combined'].dropna().tolist()
touch_list_convert1
# Out:
# [['referral', 'referral', 'referral', 'email', nan],
#  ['referral', 'display', 'display', 'email', nan],
#  ['email', 'display', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'social', 'social', nan, nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['paid_search', 'email', nan, nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['paid_search', 'referral', 'email', 'email', nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'paid_search', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['paid_search', 'social', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', 'email'],
#  ['email', 'referral', nan, nan, nan],
#  ['email', 'display', nan, nan, nan],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'display', 'referral', nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'social', 'referral', 'email', nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', 'display', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'email', 'email', nan, nan],
#  ['referral', 'social', 'email', nan, nan],
#  ['social', 'social', 'email', nan, nan],
#  ['referral', 'social', 'referral', 'email', nan],
#  ['email', 'referral', nan, nan, nan],
#  ['display', 'social', 'email', nan, nan],
#  ['display', 'referral', 'referral', 'email', nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'display', nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['email', 'display', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['display', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'email', nan, nan, nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['paid_search', 'email', nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'referral', nan, nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['referral', 'referral', 'email', 'referral', 'email'],
#  ['referral', 'email', nan, nan, nan],
#  ['display', 'email', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['display', 'display', 'email', nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['paid_search', 'referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'display', 'email'],
#  ['display', 'email', nan, nan, nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'social', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'social', 'referral', 'email'],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['referral', 'social', 'referral', 'email', nan],
#  ['referral', 'social', 'referral', 'email', nan],
#  ['email', 'social', 'referral', nan, nan],
#  ['email', 'referral', 'referral', 'email', nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['paid_search', 'display', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'email', nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['referral', 'email', 'referral', 'email', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'display', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['display', nan, nan, nan, nan],
#  ['email', 'display', 'referral', 'social', 'referral'],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['display', 'referral', 'referral', 'email', nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'display', 'referral', nan, nan],
#  ['email', 'referral', 'display', 'email', nan],
#  ['referral', 'direct', 'referral', 'email', nan],
#  ['display', 'email', nan, nan, nan],
#  ['email', 'email', 'display', 'referral', nan],
#  ['email', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'email', 'email', nan, nan],
#  ['email', 'referral', 'referral', 'referral', 'social'],
#  ['email', 'social', 'referral', 'display', nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['email', 'display', 'email', 'referral', nan],
#  ['email', nan, nan, nan, nan],
#  ['display', 'email', nan, nan, nan],
#  ['email', 'display', 'display', 'referral', nan],
#  ['referral', 'referral', 'referral', 'display', 'email'],
#  ['email', 'referral', 'paid_search', 'referral', nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['email', 'email', nan, nan, nan],
#  ['email', 'social', 'referral', 'display', nan],
#  ['social', 'display', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', 'paid_search', nan, nan, nan],
#  ['email', 'display', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['paid_search', 'display', 'referral', 'email', nan],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['email', 'referral', 'display', 'paid_search', nan],
#  ['referral', 'social', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['paid_search', 'referral', 'email', 'email', nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'email', 'referral', 'email', nan],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['referral', 'social', 'referral', 'email', nan],
#  ['referral', 'email', 'email', nan, nan],
#  ['email', 'social', nan, nan, nan],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'display', 'social', 'referral', nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', 'referral', 'email'],
#  ['referral', 'email', nan, nan, nan],
#  ['display', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'email', 'email', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'referral', 'social', 'email'],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['display', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['display', 'referral', 'referral', 'email', nan],
#  ['email', 'referral', 'social', 'social', nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'referral', 'referral', 'display'],
#  ['social', 'email', nan, nan, nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', 'referral', 'referral', 'display', nan],
#  ['referral', 'referral', 'social', 'email', nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['email', 'referral', 'paid_search', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['email', 'referral', nan, nan, nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'social', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'social', 'email', nan, nan],
#  ['social', 'display', 'referral', 'email', nan],
#  ['display', 'referral', 'email', nan, nan],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['referral', 'display', 'referral', 'email', nan],
#  ['display', 'social', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['paid_search', 'display', 'email', nan, nan],
#  ['display', 'referral', 'email', nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'display', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', 'referral', 'social', nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', 'referral', 'email', nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', 'referral', 'display', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'paid_search', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'display', 'social', 'referral', nan],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['display', 'social', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['email', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'display', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'display', 'display', 'email', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'display', 'email'],
#  ['referral', 'referral', nan, nan, nan],
#  ['email', 'email', 'referral', 'referral', 'display'],
#  ['display', 'email', nan, nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['email', 'referral', 'social', 'referral', 'referral'],
#  ['display', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['email', 'paid_search', 'referral', nan, nan],
#  ['referral', 'referral', 'social', 'email', nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'referral', nan],
#  ['display', 'referral', nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['social', 'display', 'email', nan, nan],
#  ['display', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'social', 'referral', nan, nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', 'referral', 'social', 'referral', 'referral'],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', 'display', 'referral'],
#  ['referral', 'referral', 'display', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['email', 'email', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['email', 'referral', 'display', 'referral', nan],
#  ['email', 'referral', 'display', 'referral', 'display'],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'email', 'referral', 'email', nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'display', 'referral', 'referral', nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['social', 'email', 'email', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', 'social', 'referral', nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['referral', 'email', 'referral', 'email', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['display', 'referral', 'display', 'referral', 'email'],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['display', 'display', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['display', 'email', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['social', 'referral', 'social', 'referral', 'email'],
#  ['email', 'referral', 'referral', nan, nan],
#  ['social', 'display', 'referral', nan, nan],
#  ['social', 'email', 'referral', 'display', 'display'],
#  ['referral', 'email', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'email', 'referral', 'social', nan],
#  ['paid_search', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'email', 'referral', nan, nan],
#  ['referral', 'referral', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'referral', 'display', 'social'],
#  ['display', 'social', nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', 'paid_search', 'social', nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'email', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'display', 'social', nan],
#  ['social', 'email', 'display', 'social', nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['referral', 'email', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['display', 'email', 'social', nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'email', 'referral', 'social', nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', 'referral', 'email', 'social', nan],
#  ['social', 'referral', 'social', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', 'display', 'email', 'referral', nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'paid_search', 'social'],
#  ['social', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['paid_search', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['email', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['display', 'referral', 'social', nan, nan],
#  ['referral', 'display', 'display', 'social', nan],
#  ['display', 'display', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', 'social', nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'social', 'referral', 'social', nan],
#  ['referral', 'referral', 'email', 'social', nan],
#  ['email', 'social', nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'display', nan, nan, nan],
#  ['social', 'display', 'display', 'display', nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'social', 'social'],
#  ['referral', 'social', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'display', 'social', nan],
#  ['social', 'display', nan, nan, nan],
#  ['social', 'email', 'referral', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'email', 'referral', 'social', nan],
#  ['referral', 'social', 'display', 'display', 'social'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', 'referral', 'social', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'display', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'email', 'display', nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'display', 'referral', 'social'],
#  ['email', 'referral', 'display', 'referral', 'social'],
#  ['email', 'referral', 'referral', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'paid_search', 'social', nan],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', 'referral', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'display', nan, nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['organic_search', 'social', nan, nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', 'social', nan],
#  ['social', 'display', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'social', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral', nan, nan],
#  ['email', 'social', nan, nan, nan],
#  ['social', 'paid_search', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'display', 'social', nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', 'social', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'display', 'referral', 'referral', nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'email', 'email', 'referral', 'referral'],
#  ['email', 'referral', nan, nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', 'display', 'display', 'social', nan],
#  ['referral', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'email', 'social', nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'paid_search', 'social', nan],
#  ['social', 'social', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', nan, nan, nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'display', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'display', 'email', 'social'],
#  ['display', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['social', 'referral', 'social', 'referral', nan],
#  ['social', 'referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'display', 'email', 'email', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'display', 'social'],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', 'social', 'referral', nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', 'referral', 'social', 'social'],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'paid_search', 'social', nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['social', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['paid_search', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['paid_search', nan, nan, nan, nan],
#  ['social', 'display', 'referral', 'referral', 'display'],
#  ['social', nan, nan, nan, nan],
#  ['email', 'email', 'referral', 'display', 'social'],
#  ['direct', 'social', nan, nan, nan],
#  ['email', 'display', 'email', 'referral', nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'display', nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', 'social', 'social'],
#  ['referral', 'display', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', 'display', 'social'],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'display', 'referral', nan],
#  ['email', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'social', 'social', nan],
#  ['display', 'referral', 'social', 'referral', 'social'],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'email', 'referral', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['email', 'referral', 'referral', 'paid_search', 'social'],
#  ['social', 'display', 'referral', 'social', nan],
#  ['social', 'display', 'social', nan, nan],
#  ['social', 'referral', 'social', 'referral', nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['display', 'display', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['referral', 'display', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'email', 'referral', 'social', nan],
#  ['email', 'social', nan, nan, nan],
#  ['social', 'referral', 'social', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'referral', 'email'],
#  ['social', 'social', 'email', 'social', nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'social', 'referral', 'referral'],
#  ['referral', 'display', 'social', nan, nan],
#  ['social', 'referral', 'display', 'referral', nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'display', 'referral', 'referral', nan],
#  ['email', 'referral', 'referral', 'social', nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['display', 'social', 'referral', 'social', nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['display', 'referral', 'referral', 'social', nan],
#  ['referral', 'display', 'referral', 'social', nan],
#  ['referral', 'social', 'display', 'social', nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'social', 'referral', 'referral', 'referral'],
#  ['referral', 'display', 'referral', nan, nan],
#  ['social', 'referral', 'display', 'referral', nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'display', 'referral', nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'display', 'social', 'social', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'email', 'referral', 'referral', nan],
#  ['referral', 'referral', 'email', 'referral', nan],
#  ['display', 'email', 'social', nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'display', 'referral', nan],
#  ['referral', 'referral', 'display', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'email', 'referral', 'social', nan],
#  ['social', 'display', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['social', 'display', 'social', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['paid_search', 'social', nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['email', 'referral', 'display', 'social', nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'social', 'referral', 'referral', nan],
#  ['display', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'display', 'referral', 'paid_search', 'social'],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'email', 'display', nan],
#  ['display', 'referral', 'email', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'display', nan, nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'paid_search', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'paid_search', 'referral', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'email', 'referral'],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'display', 'referral', 'email', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'email', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['social', 'email', 'referral', 'referral', nan],
#  ['display', 'email', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'social', nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'social', 'referral', 'social', nan],
#  ['social', 'email', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['display', 'social', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'paid_search', 'referral', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', 'social', 'referral'],
#  ['email', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'display', 'social'],
#  ['paid_search', 'social', 'social', nan, nan],
#  ['social', 'display', 'referral', 'email', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'display', 'referral', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'email', 'referral', 'email', nan],
#  ['social', 'display', 'referral', 'display', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['social', 'referral', 'email', 'referral', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'email', 'referral', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'email', 'referral', 'referral', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['social', 'display', nan, nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['social', 'email', 'referral', nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['paid_search', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['display', 'referral', 'referral', 'referral', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'display', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['display', 'referral', 'social', 'social', 'social'],
#  ['social', 'referral', nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'email', 'display', 'referral', 'social'],
#  ['referral', 'display', 'social', nan, nan],
#  ['referral', 'display', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['display', 'display', 'social', nan, nan],
#  ['display', 'display', 'social', 'referral', 'social'],
#  ['social', 'social', nan, nan, nan],
#  ['social', 'referral', 'email', 'social', nan],
#  ['referral', 'email', 'referral', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'email', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['referral', 'display', 'referral', 'social', nan],
#  ['social', 'email', nan, nan, nan],
#  ['display', 'social', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', 'email', 'referral', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'display', 'email', 'referral', 'social'],
#  ['referral', 'display', 'social', nan, nan],
#  ['display', 'display', 'social', nan, nan],
#  ['display', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'social', 'referral', 'social', 'display'],
#  ['email', 'referral', 'social', nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['referral', 'email', 'display', 'display', 'social'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'display', 'social', nan],
#  ['social', 'referral', 'email', 'paid_search', nan],
#  ['display', 'referral', 'social', 'social', nan],
#  ['display', 'referral', 'referral', 'social', nan],
#  ['display', 'social', nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'referral', 'email', 'referral', 'referral'],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'paid_search', 'display', nan, nan],
#  ['referral', 'display', 'referral', 'social', nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['social', 'referral', 'paid_search', nan, nan],
#  ['paid_search', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'paid_search', 'social', nan, nan],
#  ['display', 'social', 'display', 'referral', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['paid_search', 'referral', 'social', nan, nan],
#  ['social', 'social', 'referral', 'referral', nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'email', 'referral', nan],
#  ['display', 'display', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', 'social', nan],
#  ['social', 'referral', nan, nan, nan],
#  ['display', 'referral', 'referral', nan, nan],
#  ['paid_search', 'referral', 'social', nan, nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'display', 'referral', 'display'],
#  ['display', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'referral', 'paid_search', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['display', 'display', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['display', 'referral', 'referral', 'referral', 'social'],
#  ['display', 'social', 'referral', 'social', nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['social', 'referral', 'display', 'social', 'referral'],
#  ['display', nan, nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['email', 'display', 'social', 'social', nan],
#  ['paid_search', 'referral', 'email', nan, nan],
#  ['social', 'display', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'referral', 'display', 'referral', nan],
#  ['social', 'referral', 'referral', 'social', 'referral'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'display', 'referral', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'display', 'display', 'referral', nan],
#  ['social', nan, nan, nan, nan],
#  ['display', 'display', 'social', nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'display', 'social', nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'referral', 'display', 'referral', 'referral'],
#  ['social', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['email', 'referral', 'referral', 'referral', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['display', 'social', 'referral', nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'email', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['paid_search', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['display', 'paid_search', 'social', nan, nan],
#  ['social', 'referral', 'display', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', 'referral', 'social', nan],
#  ['referral', 'display', nan, nan, nan],
#  ['email', 'referral', 'social', nan, nan],
#  ...]

# %%
for i in range(len(touch_list_convert1)):
    touch_list_convert1[i] = [x for x in touch_list_convert1[i] if str(x) != 'nan']
touch_list_convert1
# Out:
# [['referral', 'referral', 'referral', 'email'],
#  ['referral', 'display', 'display', 'email'],
#  ['email', 'display', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['social', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['referral'],
#  ['referral', 'referral', 'email'],
#  ['email', 'social', 'social'],
#  ['email', 'referral', 'email'],
#  ['email'],
#  ['paid_search', 'email'],
#  ['email', 'referral'],
#  ['paid_search', 'referral', 'email', 'email'],
#  ['email', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral', 'paid_search'],
#  ['referral', 'email'],
#  ['paid_search', 'social', 'email'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral', 'email'],
#  ['social', 'email'],
#  ['referral', 'referral', 'referral', 'social', 'email'],
#  ['email', 'referral'],
#  ['email', 'display'],
#  ['social', 'referral', 'referral', 'email'],
#  ['email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'display', 'referral'],
#  ['email'],
#  ['referral', 'social', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'display'],
#  ['referral', 'referral', 'email'],
#  ['email', 'email', 'email'],
#  ['referral', 'social', 'email'],
#  ['social', 'social', 'email'],
#  ['referral', 'social', 'referral', 'email'],
#  ['email', 'referral'],
#  ['display', 'social', 'email'],
#  ['display', 'referral', 'referral', 'email'],
#  ['social', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral', 'display'],
#  ['referral'],
#  ['email', 'display'],
#  ['referral', 'email'],
#  ['display', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'email'],
#  ['referral', 'display', 'email'],
#  ['email'],
#  ['email', 'referral', 'referral'],
#  ['paid_search', 'email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'referral'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'email', 'referral', 'email'],
#  ['referral', 'email'],
#  ['display', 'email'],
#  ['referral', 'email'],
#  ['referral'],
#  ['display', 'display', 'email'],
#  ['social', 'email'],
#  ['paid_search', 'referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'display', 'email'],
#  ['display', 'email'],
#  ['referral', 'display', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['email'],
#  ['referral', 'social', 'email'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'social', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral', 'email'],
#  ['referral', 'social', 'referral', 'email'],
#  ['referral', 'social', 'referral', 'email'],
#  ['email', 'social', 'referral'],
#  ['email', 'referral', 'referral', 'email'],
#  ['referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['paid_search', 'display', 'email'],
#  ['referral', 'email'],
#  ['referral', 'email'],
#  ['email', 'email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['referral', 'email', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'display', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['display'],
#  ['email', 'display', 'referral', 'social', 'referral'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'email'],
#  ['email', 'referral'],
#  ['display', 'referral', 'referral', 'email'],
#  ['referral', 'display', 'email'],
#  ['email', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'display', 'referral'],
#  ['email', 'referral', 'display', 'email'],
#  ['referral', 'direct', 'referral', 'email'],
#  ['display', 'email'],
#  ['email', 'email', 'display', 'referral'],
#  ['email'],
#  ['social', 'referral', 'referral', 'email'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'email', 'email'],
#  ['email', 'referral', 'referral', 'referral', 'social'],
#  ['email', 'social', 'referral', 'display'],
#  ['email', 'referral'],
#  ['email'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['email', 'display', 'email', 'referral'],
#  ['email'],
#  ['display', 'email'],
#  ['email', 'display', 'display', 'referral'],
#  ['referral', 'referral', 'referral', 'display', 'email'],
#  ['email', 'referral', 'paid_search', 'referral'],
#  ['referral', 'display', 'email'],
#  ['email', 'email'],
#  ['email', 'social', 'referral', 'display'],
#  ['social', 'display', 'email'],
#  ['referral', 'email'],
#  ['referral', 'email'],
#  ['email'],
#  ['email', 'referral', 'referral'],
#  ['email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral'],
#  ['email', 'paid_search'],
#  ['email', 'display'],
#  ['email'],
#  ['referral', 'email'],
#  ['email'],
#  ['paid_search', 'display', 'referral', 'email'],
#  ['social', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'display', 'paid_search'],
#  ['referral', 'social', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['email', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['paid_search', 'referral', 'email', 'email'],
#  ['email', 'referral', 'email'],
#  ['email', 'referral'],
#  ['referral', 'email', 'referral', 'email'],
#  ['social', 'referral', 'referral', 'email'],
#  ['referral', 'social', 'referral', 'email'],
#  ['referral', 'email', 'email'],
#  ['email', 'social'],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['email'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral', 'referral'],
#  ['email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'display', 'social', 'referral'],
#  ['social', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'referral', 'email'],
#  ['referral', 'email'],
#  ['display', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'email', 'email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'social', 'email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['display', 'email'],
#  ['referral', 'referral', 'email'],
#  ['display', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'social', 'social'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['social', 'referral'],
#  ['referral', 'email'],
#  ['email', 'referral', 'referral', 'referral', 'display'],
#  ['social', 'email'],
#  ['referral', 'display', 'email'],
#  ['email', 'referral'],
#  ['email', 'referral', 'referral', 'display'],
#  ['referral', 'referral', 'social', 'email'],
#  ['email', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral'],
#  ['referral', 'display', 'social'],
#  ['email', 'referral', 'paid_search'],
#  ['referral', 'email'],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['email', 'referral'],
#  ['email', 'referral', 'social'],
#  ['email', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'social', 'email'],
#  ['email'],
#  ['social', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['social', 'email'],
#  ['email'],
#  ['referral', 'email'],
#  ['referral', 'social', 'email'],
#  ['social', 'display', 'referral', 'email'],
#  ['display', 'referral', 'email'],
#  ['social', 'referral', 'referral', 'email'],
#  ['referral', 'display', 'referral', 'email'],
#  ['display', 'social', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral'],
#  ['referral'],
#  ['referral', 'referral', 'email'],
#  ['paid_search', 'display', 'email'],
#  ['display', 'referral', 'email'],
#  ['referral'],
#  ['email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral', 'display'],
#  ['email'],
#  ['email', 'referral', 'referral', 'social'],
#  ['email', 'referral', 'email'],
#  ['email'],
#  ['email', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral'],
#  ['email', 'referral', 'display'],
#  ['email'],
#  ['referral', 'paid_search', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email'],
#  ['email', 'display', 'social', 'referral'],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['display', 'social', 'email'],
#  ['email', 'referral'],
#  ['social', 'referral', 'email'],
#  ['email', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'display', 'email'],
#  ['referral', 'email'],
#  ['referral', 'display', 'display', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral'],
#  ['referral', 'referral', 'referral', 'display', 'email'],
#  ['referral', 'referral'],
#  ['email', 'email', 'referral', 'referral', 'display'],
#  ['display', 'email'],
#  ['email', 'referral'],
#  ['social', 'social', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral', 'email'],
#  ['email'],
#  ['social', 'referral', 'referral'],
#  ['email', 'referral', 'social', 'referral', 'referral'],
#  ['display'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['referral', 'display', 'email'],
#  ['email', 'paid_search', 'referral'],
#  ['referral', 'referral', 'social', 'email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['referral'],
#  ['referral'],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'referral'],
#  ['display', 'referral'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'email'],
#  ['email', 'referral'],
#  ['referral', 'email'],
#  ['social', 'display', 'email'],
#  ['display', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'social', 'referral'],
#  ['social', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['email', 'referral'],
#  ['email', 'referral', 'social', 'referral', 'referral'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral'],
#  ['email', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'display', 'referral'],
#  ['referral', 'referral', 'display', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['email', 'referral'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['email', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'social'],
#  ['email', 'referral', 'display', 'referral'],
#  ['email', 'referral', 'display', 'referral', 'display'],
#  ['referral', 'email'],
#  ['email', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'email', 'referral', 'email'],
#  ['referral', 'email'],
#  ['email', 'display', 'referral', 'referral'],
#  ['email'],
#  ['referral', 'referral', 'email'],
#  ['social', 'email', 'email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral', 'social', 'referral'],
#  ['referral', 'email'],
#  ['email', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['referral', 'email', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'display', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['email'],
#  ['display', 'referral', 'display', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['display', 'display', 'email'],
#  ['email'],
#  ['display', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['social', 'referral', 'social', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['social', 'display', 'referral'],
#  ['social', 'email', 'referral', 'display', 'display'],
#  ['referral', 'email', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'email', 'referral', 'social'],
#  ['paid_search', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['social', 'email', 'referral'],
#  ['referral', 'referral', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'referral', 'display', 'social'],
#  ['display', 'social'],
#  ['referral'],
#  ['referral', 'referral', 'paid_search', 'social'],
#  ['display', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['social', 'referral', 'social'],
#  ['referral', 'email', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'email', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'display', 'social'],
#  ['social', 'email', 'display', 'social'],
#  ['email', 'referral', 'social'],
#  ['referral', 'email', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral'],
#  ['social'],
#  ['social'],
#  ['referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['social', 'referral'],
#  ['display', 'email', 'social'],
#  ['display', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'social', 'referral'],
#  ['referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'email', 'referral', 'social'],
#  ['referral', 'social', 'social'],
#  ['social', 'referral', 'email', 'social'],
#  ['social', 'referral', 'social', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'email'],
#  ['display', 'social'],
#  ['referral', 'social'],
#  ['display', 'social'],
#  ['display', 'social'],
#  ['referral', 'social', 'social'],
#  ['social', 'display', 'email', 'referral'],
#  ['social', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'paid_search', 'social'],
#  ['social', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['paid_search', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social'],
#  ['referral', 'social'],
#  ['email', 'social'],
#  ['social'],
#  ['social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['display', 'referral', 'social'],
#  ['referral', 'display', 'display', 'social'],
#  ['display', 'display', 'referral', 'social'],
#  ['referral', 'referral', 'social', 'social'],
#  ['social', 'referral', 'social'],
#  ['referral', 'social', 'referral', 'social'],
#  ['referral', 'referral', 'email', 'social'],
#  ['email', 'social'],
#  ['social', 'referral'],
#  ['social'],
#  ['social', 'display'],
#  ['social', 'display', 'display', 'display'],
#  ['referral', 'email', 'social'],
#  ['referral', 'referral', 'referral', 'social', 'social'],
#  ['referral', 'social', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'display', 'social'],
#  ['social', 'display'],
#  ['social', 'email', 'referral'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'email', 'referral', 'social'],
#  ['referral', 'social', 'display', 'display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social', 'referral', 'social', 'social'],
#  ['social'],
#  ['social', 'referral'],
#  ['social'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'display', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'email', 'display'],
#  ['social'],
#  ['social', 'referral', 'social'],
#  ['referral', 'referral', 'display', 'referral', 'social'],
#  ['email', 'referral', 'display', 'referral', 'social'],
#  ['email', 'referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'paid_search', 'social'],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'social', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'display'],
#  ['display', 'referral', 'social'],
#  ['social', 'social'],
#  ['social'],
#  ['display', 'social'],
#  ['social', 'referral'],
#  ['social'],
#  ['organic_search', 'social'],
#  ['display', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social', 'social'],
#  ['social', 'display', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['social', 'referral'],
#  ['social', 'social', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['email', 'social'],
#  ['social', 'paid_search'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'display', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral', 'social', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'display', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'display', 'referral', 'referral'],
#  ['social'],
#  ['social', 'email', 'email', 'referral', 'referral'],
#  ['email', 'referral'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral', 'display', 'display', 'social'],
#  ['referral', 'referral', 'referral'],
#  ['referral', 'referral', 'email', 'social'],
#  ['email', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'paid_search', 'social'],
#  ['social', 'social', 'referral', 'referral', 'referral'],
#  ['referral', 'referral'],
#  ['social', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'display', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'display', 'email', 'social'],
#  ['display', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral'],
#  ['social', 'referral', 'social', 'referral'],
#  ['social', 'referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'social'],
#  ['social', 'display', 'email', 'email'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'display', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral', 'social', 'social'],
#  ['social'],
#  ['social', 'social'],
#  ['referral', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'email'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'social', 'social', 'referral'],
#  ['display', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social', 'referral', 'social', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral'],
#  ['referral', 'referral', 'paid_search', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['social', 'social'],
#  ['referral', 'social'],
#  ['paid_search', 'referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'email'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral'],
#  ['social', 'referral', 'referral'],
#  ['social', 'social', 'referral'],
#  ['social', 'referral', 'email'],
#  ['referral', 'display', 'social'],
#  ['paid_search'],
#  ['social', 'display', 'referral', 'referral', 'display'],
#  ['social'],
#  ['email', 'email', 'referral', 'display', 'social'],
#  ['direct', 'social'],
#  ['email', 'display', 'email', 'referral'],
#  ['social'],
#  ['social', 'social'],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['social', 'referral'],
#  ['referral', 'email', 'social'],
#  ['referral', 'display', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'email', 'social'],
#  ['social', 'referral', 'referral', 'display'],
#  ['social'],
#  ['social', 'referral', 'referral', 'social', 'social'],
#  ['referral', 'display', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social', 'display', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'display', 'referral'],
#  ['email', 'social'],
#  ['referral', 'social'],
#  ['social'],
#  ['referral', 'referral'],
#  ['referral', 'referral', 'social', 'social'],
#  ['display', 'referral', 'social', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'email', 'referral'],
#  ['social'],
#  ['email', 'referral', 'referral', 'paid_search', 'social'],
#  ['social', 'display', 'referral', 'social'],
#  ['social', 'display', 'social'],
#  ['social', 'referral', 'social', 'referral'],
#  ['social'],
#  ['social', 'social'],
#  ['referral', 'display', 'social'],
#  ['display', 'display', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'email'],
#  ['referral', 'display', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'email', 'referral', 'social'],
#  ['email', 'social'],
#  ['social', 'referral', 'social', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral', 'email'],
#  ['social', 'social', 'email', 'social'],
#  ['referral', 'display', 'social'],
#  ['social', 'email'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['social', 'referral', 'social', 'referral', 'referral'],
#  ['referral', 'display', 'social'],
#  ['social', 'referral', 'display', 'referral'],
#  ['referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'social'],
#  ['display', 'referral', 'social'],
#  ['social'],
#  ['referral', 'display', 'referral', 'referral'],
#  ['email', 'referral', 'referral', 'social'],
#  ['social', 'social', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral'],
#  ['referral', 'display', 'social'],
#  ['referral', 'email', 'social'],
#  ['social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social'],
#  ['display', 'social', 'referral', 'social'],
#  ['referral', 'referral'],
#  ['display', 'referral', 'referral', 'social'],
#  ['referral', 'display', 'referral', 'social'],
#  ['referral', 'social', 'display', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'display', 'social'],
#  ['social', 'referral'],
#  ['social', 'social', 'referral', 'referral', 'referral'],
#  ['referral', 'display', 'referral'],
#  ['social', 'referral', 'display', 'referral'],
#  ['social'],
#  ['social', 'display', 'referral'],
#  ['referral', 'social', 'social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'display', 'social', 'social'],
#  ['social', 'referral', 'referral'],
#  ['social', 'email', 'referral', 'referral'],
#  ['referral', 'referral', 'email', 'referral'],
#  ['display', 'email', 'social'],
#  ['referral'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'display', 'referral'],
#  ['referral', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'email', 'referral', 'social'],
#  ['social', 'display'],
#  ['social', 'referral', 'referral'],
#  ['social', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'social'],
#  ['display', 'referral', 'social'],
#  ['social', 'display', 'social', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'social'],
#  ['paid_search', 'social'],
#  ['display', 'social'],
#  ['social', 'social'],
#  ['email', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'social', 'referral', 'referral'],
#  ['display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social', 'social'],
#  ['social', 'referral'],
#  ['referral', 'social', 'social'],
#  ['social'],
#  ['social', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['social'],
#  ['referral', 'display', 'referral', 'paid_search', 'social'],
#  ['social', 'referral'],
#  ['referral', 'social'],
#  ['social', 'referral', 'email', 'display'],
#  ['display', 'referral', 'email', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social', 'social'],
#  ['social'],
#  ['social', 'referral', 'display'],
#  ['social', 'social', 'referral'],
#  ['social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social'],
#  ['display', 'social'],
#  ['referral', 'social'],
#  ['social', 'paid_search'],
#  ['social'],
#  ['social', 'referral'],
#  ['social', 'paid_search', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'email', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'display', 'referral', 'email'],
#  ['referral', 'social'],
#  ['social'],
#  ['referral', 'email', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['display', 'social'],
#  ['social', 'email', 'referral', 'referral'],
#  ['display', 'email', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'social'],
#  ['display', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'social', 'referral', 'social'],
#  ['social', 'email', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'social'],
#  ['social'],
#  ['social', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral'],
#  ['referral'],
#  ['referral', 'social', 'social'],
#  ['display', 'social', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'paid_search', 'referral'],
#  ['social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral', 'social', 'referral'],
#  ['email', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'display', 'social'],
#  ['paid_search', 'social', 'social'],
#  ['social', 'display', 'referral', 'email'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'display', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'email', 'referral', 'email'],
#  ['social', 'display', 'referral', 'display'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral', 'display', 'social'],
#  ['social', 'referral', 'email', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'email', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'email', 'referral', 'referral', 'social'],
#  ['social'],
#  ['social'],
#  ['referral', 'display', 'social'],
#  ['social', 'display'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['social', 'email', 'referral'],
#  ['referral', 'referral'],
#  ['referral', 'referral', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['paid_search', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'display', 'social'],
#  ['display', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['social'],
#  ['referral', 'display'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['display', 'referral', 'social', 'social', 'social'],
#  ['social', 'referral'],
#  ['display', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'email', 'display', 'referral', 'social'],
#  ['referral', 'display', 'social'],
#  ['referral', 'display'],
#  ['referral', 'referral', 'social'],
#  ['email'],
#  ['display', 'display', 'social'],
#  ['display', 'display', 'social', 'referral', 'social'],
#  ['social', 'social'],
#  ['social', 'referral', 'email', 'social'],
#  ['referral', 'email', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'email', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'social'],
#  ['referral', 'display', 'referral', 'social'],
#  ['social', 'email'],
#  ['display', 'social', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'social', 'social'],
#  ['social', 'email', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'display', 'email', 'referral', 'social'],
#  ['referral', 'display', 'social'],
#  ['display', 'display', 'social'],
#  ['display', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['social', 'social', 'referral', 'social', 'display'],
#  ['email', 'referral', 'social'],
#  ['display', 'social'],
#  ['social', 'social', 'referral'],
#  ['referral', 'email', 'display', 'display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral'],
#  ['referral', 'referral', 'display', 'social'],
#  ['social', 'referral', 'email', 'paid_search'],
#  ['display', 'referral', 'social', 'social'],
#  ['display', 'referral', 'referral', 'social'],
#  ['display', 'social'],
#  ['social', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['social', 'referral', 'email', 'referral', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'email', 'social'],
#  ['referral', 'email', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['social'],
#  ['social', 'paid_search', 'display'],
#  ['referral', 'display', 'referral', 'social'],
#  ['referral', 'display', 'social'],
#  ['social', 'referral', 'paid_search'],
#  ['paid_search', 'referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'paid_search', 'social'],
#  ['display', 'social', 'display', 'referral', 'social'],
#  ['social'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral', 'display', 'social'],
#  ['social'],
#  ['paid_search', 'referral', 'social'],
#  ['social', 'social', 'referral', 'referral'],
#  ['social'],
#  ['social', 'referral', 'email', 'referral'],
#  ['display', 'display', 'referral', 'social'],
#  ['referral', 'referral', 'social', 'social'],
#  ['social', 'referral'],
#  ['display', 'referral', 'referral'],
#  ['paid_search', 'referral', 'social'],
#  ['referral', 'email', 'social'],
#  ['social'],
#  ['social', 'referral', 'display', 'referral', 'display'],
#  ['display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['social', 'referral', 'paid_search'],
#  ['social', 'referral'],
#  ['display', 'display', 'social'],
#  ['social'],
#  ['social', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['display', 'referral', 'referral', 'referral', 'social'],
#  ['display', 'social', 'referral', 'social'],
#  ['referral', 'email', 'social'],
#  ['social', 'referral', 'display', 'social', 'referral'],
#  ['display'],
#  ['social', 'referral', 'social'],
#  ['email', 'display', 'social', 'social'],
#  ['paid_search', 'referral', 'email'],
#  ['social', 'display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['social', 'referral'],
#  ['social', 'referral', 'display', 'referral'],
#  ['social', 'referral', 'referral', 'social', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'display', 'referral'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['social'],
#  ['referral', 'social', 'social'],
#  ['referral'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'display', 'display', 'referral'],
#  ['social'],
#  ['display', 'display', 'social'],
#  ['display', 'social'],
#  ['social', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'referral', 'display', 'social'],
#  ['social', 'referral'],
#  ['social', 'referral', 'display', 'referral', 'referral'],
#  ['social', 'social'],
#  ['referral', 'referral', 'social'],
#  ['email', 'referral', 'referral', 'referral', 'social'],
#  ['social'],
#  ['social', 'referral', 'referral'],
#  ['display', 'social', 'referral'],
#  ['referral', 'display', 'social'],
#  ['referral', 'email', 'social'],
#  ['social'],
#  ['social'],
#  ['display', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral'],
#  ['referral', 'email', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['paid_search', 'referral', 'social'],
#  ['social'],
#  ['social', 'referral', 'referral'],
#  ['display', 'paid_search', 'social'],
#  ['social', 'referral', 'display'],
#  ['social'],
#  ['social', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'social', 'referral', 'social'],
#  ['referral', 'display'],
#  ['email', 'referral', 'social'],
#  ...]

# %%
counts = dict()



for i in range(len(touch_list_convert1)):
    if len(touch_list_convert1[i]) == 2:
        for j in range(len(touch_list_convert1[i])):
            counts[touch_list_convert1[i][j]] = counts.get(touch_list_convert1[i][j],0)+0.5
    elif len(touch_list_convert1[i]) == 3:
        for j in range(len(touch_list_convert1[i])):
            counts[touch_list_convert1[i][j]] = counts.get(touch_list_convert1[i][j],0)+ 1/3
    elif len(touch_list_convert1[i]) == 4:
        for j in range(len(touch_list_convert1[i])):
            counts[touch_list_convert1[i][j]] = counts.get(touch_list_convert1[i][j],0)+ 1/4
    elif len(touch_list_convert1[i]) == 5:
        for j in range(len(touch_list_convert1[i])):
            counts[touch_list_convert1[i][j]] = counts.get(touch_list_convert1[i][j],0)+ 1/5
    else:
        for j in range(len(touch_list_convert1[i])):
            counts[touch_list_convert1[i][j]] = counts.get(touch_list_convert1[i][j],0)+ 1

counts
# Out:
# {'referral': 1517.0999999999979,
#  'email': 251.13333333333372,
#  'display': 439.26666666666273,
#  'social': 484.583333333328,
#  'paid_search': 128.04999999999984,
#  'direct': 1.9166666666666665,
#  'organic_search': 1.9499999999999997}

# %%
convert_tier1 = pd.DataFrame(list(counts.items()),columns = ['channel','converts'])
convert_tier1
# Out:
#           channel     converts
# 0        referral  1517.100000
# 1           email   251.133333
# 2         display   439.266667
# 3          social   484.583333
# 4     paid_search   128.050000
# 5          direct     1.916667
# 6  organic_search     1.950000

# %%
convert2_combined = convert2.iloc[:,1:6]
convert2_combined['combined']= convert2_combined.values.tolist()
convert2_combined.drop(convert2_combined.iloc[:, 0:5], inplace=True, axis=1)
convert2_combined
# Out:
#                                              combined
# 11354       [display, referral, referral, email, nan]
# 11355           [referral, referral, email, nan, nan]
# 11356               [email, social, social, nan, nan]
# 11357                  [social, email, nan, nan, nan]
# 11358              [email, referral, email, nan, nan]
# ...                                               ...
# 26941                [referral, email, nan, nan, nan]
# 26942        [referral, referral, referral, nan, nan]
# 34041  [organic_search, referral, referral, nan, nan]
# 34042  [referral, referral, organic_search, nan, nan]
# 34055     [direct, referral, referral, referral, nan]
#
# [4892 rows x 1 columns]

# %%
touch_list_convert2 = convert2_combined['combined'].dropna().tolist()
touch_list_convert2
# Out:
# [['display', 'referral', 'referral', 'email', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'social', 'social', nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['paid_search', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['email', 'display', 'email', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', 'email', 'email'],
#  ['social', 'social', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'display', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'email', nan, nan],
#  ['paid_search', 'referral', 'display', 'referral', 'email'],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'paid_search', 'paid_search', 'referral', nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['display', 'email', nan, nan, nan],
#  ['email', 'email', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'display', 'referral', nan, nan],
#  ['email', 'email', 'referral', 'referral', 'referral'],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'display', 'referral', 'email', nan],
#  ['referral', 'referral', 'referral', 'paid_search', 'email'],
#  ['email', 'referral', 'display', nan, nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['email', 'referral', 'email', 'referral', nan],
#  ['email', 'email', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'email', 'referral', nan, nan],
#  ['referral', 'display', 'referral', 'email', nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'social', 'referral', 'email', nan],
#  ['display', 'social', 'email', nan, nan],
#  ['email', 'referral', 'display', 'referral', nan],
#  ['email', 'referral', 'display', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'display', 'referral', nan, nan],
#  ['referral', 'email', 'referral', 'email', nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['email', 'social', 'display', 'referral', 'referral'],
#  ['email', nan, nan, nan, nan],
#  ['display', 'paid_search', 'referral', 'email', nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['paid_search', 'referral', 'display', 'email', nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'email', 'email', nan, nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'email', 'email'],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'display', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'email', 'email', 'display', 'referral'],
#  ['referral', 'referral', 'email', nan, nan],
#  ['display', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', 'display', nan, nan],
#  ['display', 'referral', 'referral', 'email', nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['social', 'display', 'email', nan, nan],
#  ['email', 'referral', 'referral', 'referral', 'display'],
#  ['referral', 'organic_search', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['social', 'referral', 'email', 'social', 'email'],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'social', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['display', 'display', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['referral', 'referral', 'referral', 'social', 'email'],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['email', 'email', 'social', nan, nan],
#  ['display', 'referral', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'social', 'email', nan, nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['email', 'social', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'social', 'referral', nan],
#  ['email', 'referral', 'referral', 'display', 'email'],
#  ['referral', 'referral', 'email', 'email', nan],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'display', 'social', nan, nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['display', 'email', nan, nan, nan],
#  ['display', 'email', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['paid_search', 'email', nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'social', 'email', nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'social', 'email', nan, nan],
#  ['referral', 'social', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['social', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'email', 'email', nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', 'email', nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'social', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['paid_search', nan, nan, nan, nan],
#  ['email', 'display', nan, nan, nan],
#  ['email', 'referral', 'referral', 'email', 'referral'],
#  ['social', 'referral', 'paid_search', 'email', nan],
#  ['display', 'email', 'email', nan, nan],
#  ['email', 'social', 'referral', 'referral', nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'social', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'paid_search', 'referral', nan, nan],
#  ['referral', 'social', 'display', 'referral', 'email'],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'social', 'email', nan, nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['email', 'referral', 'paid_search', nan, nan],
#  ['email', 'referral', 'display', 'referral', nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', 'referral', 'display', 'email', nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['social', 'display', 'email', nan, nan],
#  ['referral', 'display', 'referral', 'email', nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['display', 'email', nan, nan, nan],
#  ['email', 'display', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'email', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['referral', 'paid_search', 'referral', 'email', nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['email', 'referral', 'referral', 'display', nan],
#  ['display', 'referral', 'email', nan, nan],
#  ['email', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['display', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['paid_search', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['paid_search', 'social', 'referral', 'email', nan],
#  ['referral', 'paid_search', 'referral', 'email', nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'display', 'email', 'referral', 'social'],
#  ['email', 'referral', 'display', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'organic_search', 'referral', 'email', nan],
#  ['display', 'display', 'email', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'display', 'referral'],
#  ['referral', 'referral', 'paid_search', 'email', nan],
#  ['email', 'referral', 'organic_search', 'referral', 'display'],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'email', 'referral', nan],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['display', 'referral', 'email', nan, nan],
#  ['social', 'display', 'referral', 'email', nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'social', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', 'social', 'display', nan],
#  ['social', 'email', 'referral', 'email', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'email', nan, nan, nan],
#  ['email', 'social', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['display', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'email', 'referral', 'referral', nan],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'social', 'social', 'email', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'social', 'email', nan, nan],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'social', 'email', nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['referral', 'display', 'referral', 'display', 'email'],
#  ['display', 'referral', 'display', 'referral', 'email'],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'email', 'referral', 'email', nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'email', nan, nan, nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['display', 'social', 'referral', 'email', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'referral', 'email', 'email'],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'social', 'referral', 'email', nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'display', 'referral', 'email', nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['display', 'referral', 'email', nan, nan],
#  ['display', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'email', 'email', nan, nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['email', nan, nan, nan, nan],
#  ['display', 'referral', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'email', 'email', 'email', nan],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['email', 'referral', 'email', 'referral', nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'display', 'social', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'display', nan, nan, nan],
#  ['email', 'referral', 'social', 'referral', nan],
#  ['social', 'referral', 'email', 'email', nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['referral', 'display', 'referral', 'email', nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'social', 'referral', 'referral', 'email'],
#  ['email', 'social', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['social', 'email', 'email', nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['email', 'email', 'email', nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['referral', 'display', 'email', nan, nan],
#  ['social', 'display', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'social', 'display', nan, nan],
#  ['email', 'paid_search', nan, nan, nan],
#  ['referral', 'email', 'display', 'email', nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'email', 'social', 'email', nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'display', 'referral', 'email', nan],
#  ['referral', 'email', 'social', 'email', nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['direct', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['email', 'referral', 'paid_search', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['display', 'display', nan, nan, nan],
#  ['social', 'display', 'social', 'referral', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'email', 'display', nan, nan],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['social', 'social', 'display', 'display', 'referral'],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['display', 'email', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'display', 'referral', 'social', nan],
#  ['social', 'referral', 'display', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'referral', 'social', 'referral', 'social'],
#  ['social', 'email', 'referral', nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['social', 'referral', 'display', nan, nan],
#  ['display', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'display', 'social', 'referral', 'paid_search'],
#  ['referral', 'social', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'social', 'social', nan],
#  ['referral', 'display', 'referral', 'referral', 'social'],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'social', 'social', nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'paid_search', 'referral', 'social'],
#  ['social', 'referral', 'social', 'display', 'email'],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['social', 'display', 'email', nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', 'display', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'paid_search', 'social', nan],
#  ['referral', 'referral', 'social', 'referral', 'social'],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'email', 'referral', nan, nan],
#  ['referral', 'email', 'display', 'display', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['display', 'email', 'referral', 'social', nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'display', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['display', 'referral', nan, nan, nan],
#  ['social', 'referral', 'referral', 'paid_search', nan],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'display', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'referral', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'paid_search', 'social', nan, nan],
#  ['referral', 'referral', 'social', 'social', nan],
#  ['paid_search', 'display', 'referral', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'display', nan, nan, nan],
#  ['social', 'email', 'referral', 'referral', 'referral'],
#  ['email', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'paid_search', 'referral', 'referral', nan],
#  ['display', 'display', 'referral', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['display', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'social', 'social', nan, nan],
#  ['referral', 'social', 'display', 'social', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['display', nan, nan, nan, nan],
#  ['referral', 'referral', 'display', 'social', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['display', 'referral', 'social', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['email', 'referral', 'display', 'referral', 'social'],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'paid_search', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'display', 'social', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'display', 'referral', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'email', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', nan, nan],
#  ['referral', 'display', 'referral', 'social', nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['email', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'social', 'referral', 'referral', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', 'display', 'referral', nan, nan],
#  ['social', 'display', 'referral', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'display', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['email', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['display', 'social', 'social', nan, nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['referral', 'social', 'referral', 'display', 'social'],
#  ['referral', 'paid_search', 'social', nan, nan],
#  ['display', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['social', 'social', 'referral', 'referral', nan],
#  ['social', 'email', 'referral', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['referral', 'display', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['email', 'display', 'referral', 'social', nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'referral', 'display', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', 'referral', nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['display', 'social', 'social', nan, nan],
#  ['display', 'email', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'display', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'email', 'email', 'referral', nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['email', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['paid_search', 'social', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', 'email', 'paid_search'],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'display', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['email', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'email', 'referral', nan, nan],
#  ['social', 'referral', 'email', 'referral', nan],
#  ['referral', 'referral', 'display', 'social', nan],
#  ['display', 'social', 'social', nan, nan],
#  ['email', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'social', 'referral', 'referral', 'social'],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['display', 'display', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['display', 'referral', 'email', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['social', 'social', 'referral', 'email', 'referral'],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'display', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', 'referral', 'social', nan],
#  ['referral', 'email', 'referral', 'social', nan],
#  ['referral', 'organic_search', nan, nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'display', nan, nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['social', 'email', 'display', 'referral', nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'display', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['paid_search', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', 'social', 'social'],
#  ['social', 'display', 'referral', 'referral', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['display', 'social', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'referral', 'display', 'referral', 'paid_search'],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'email', 'referral', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'paid_search', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', 'display', 'social', nan, nan],
#  ['social', 'referral', 'social', 'referral', nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'email', 'referral', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['email', 'paid_search', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['social', 'display', 'display', nan, nan],
#  ['social', 'referral', 'social', 'referral', nan],
#  ['referral', 'email', 'referral', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', 'email', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['organic_search', 'display', 'referral', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'social', 'display', 'social'],
#  ['social', 'social', 'referral', nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['social', 'paid_search', 'referral', nan, nan],
#  ['social', 'referral', 'display', nan, nan],
#  ['referral', 'social', 'email', 'social', nan],
#  ['referral', 'referral', 'referral', nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['email', 'social', 'referral', 'social', nan],
#  ['referral', 'email', 'referral', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', 'referral', 'social', nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'display', 'paid_search', 'referral', nan],
#  ['social', 'paid_search', 'referral', 'referral', nan],
#  ['social', 'email', 'referral', 'direct', 'referral'],
#  ['email', 'referral', 'social', nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['referral', 'social', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['social', 'social', 'referral', 'social', nan],
#  ['referral', 'paid_search', 'referral', 'social', 'social'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'email', 'referral', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'display', 'display', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['paid_search', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'email', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'email', 'referral', 'social'],
#  ['display', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'display', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', 'display', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['paid_search', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'display', 'social', nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['paid_search', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'display', 'referral', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'display', 'social', 'social'],
#  ['social', 'display', 'referral', 'referral', nan],
#  ['referral', 'paid_search', 'referral', 'social', nan],
#  ['social', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'display', 'social', nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'social', 'referral', 'referral', nan],
#  ['display', 'social', 'social', nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['social', 'referral', 'paid_search', 'referral', 'referral'],
#  ['social', 'social', 'social', nan, nan],
#  ['referral', 'referral', 'social', 'social', 'social'],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['social', 'social', 'social', nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['email', 'display', 'paid_search', 'referral', 'social'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['social', 'referral', 'display', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'email', 'referral', 'social', nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['paid_search', 'referral', 'social', nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', 'display', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'email', 'email', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', 'paid_search', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'social', 'referral', 'referral', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'display', 'referral', nan],
#  ['referral', 'social', 'display', 'social', nan],
#  ['social', 'email', 'referral', 'referral', nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['social', 'display', 'referral', 'display', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'display', 'referral', 'social'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', 'referral', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['paid_search', 'referral', 'referral', 'social', nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'display', 'referral', 'social', 'social'],
#  ['display', 'display', nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'display', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'email', 'referral', nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['social', 'referral', 'email', 'referral', nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'social', 'referral', 'social', nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['organic_search', 'referral', 'social', nan, nan],
#  ['email', 'referral', 'email', 'social', nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['social', 'social', 'email', 'email', 'referral'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'email', 'referral', 'email', 'social'],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'referral', 'paid_search', 'email', 'referral'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'email', 'referral', 'referral', 'email'],
#  ['display', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['referral', 'social', 'referral', 'social', nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['referral', 'referral', 'display', 'social', nan],
#  ['display', 'display', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['social', 'referral', 'display', nan, nan],
#  ['display', 'paid_search', 'social', nan, nan],
#  ['referral', 'social', 'social', 'social', nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'referral', 'social', 'social'],
#  ['social', 'referral', nan, nan, nan],
#  ['display', 'referral', 'paid_search', 'social', nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'display', 'referral', 'social', nan],
#  ['referral', 'social', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['display', nan, nan, nan, nan],
#  ['social', 'referral', 'display', 'referral', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['display', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['paid_search', 'referral', 'display', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'paid_search', nan, nan],
#  ['referral', 'referral', 'email', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['display', 'display', 'referral', 'referral', nan],
#  ['social', nan, nan, nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['social', 'display', 'social', nan, nan],
#  ['display', 'email', 'display', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'display', nan, nan],
#  ['social', 'display', 'social', nan, nan],
#  ['social', 'social', 'referral', 'social', nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['display', 'email', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['social', 'display', 'referral', nan, nan],
#  ['email', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'display', 'display', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'email', 'email', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'display', 'social', 'social', nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', nan, nan, nan, nan],
#  ...]

# %%
for i in range(len(touch_list_convert2)):
    touch_list_convert2[i] = [x for x in touch_list_convert2[i] if str(x) != 'nan']
touch_list_convert2
# Out:
# [['display', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'social', 'social'],
#  ['social', 'email'],
#  ['email', 'referral', 'email'],
#  ['referral', 'email'],
#  ['referral'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['paid_search', 'referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['email', 'display', 'email'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social', 'email', 'email'],
#  ['social', 'social', 'email'],
#  ['referral', 'email'],
#  ['email'],
#  ['referral', 'display', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['paid_search', 'referral', 'display', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email'],
#  ['referral', 'referral', 'email'],
#  ['social', 'referral', 'email'],
#  ['email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['email', 'paid_search', 'paid_search', 'referral'],
#  ['email', 'referral'],
#  ['email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['display', 'email'],
#  ['email', 'email', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['social', 'email'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'display', 'referral'],
#  ['email', 'email', 'referral', 'referral', 'referral'],
#  ['referral', 'email'],
#  ['referral', 'display', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'paid_search', 'email'],
#  ['email', 'referral', 'display'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['email', 'referral', 'email', 'referral'],
#  ['email', 'email', 'email'],
#  ['email', 'referral'],
#  ['email'],
#  ['email', 'email', 'referral'],
#  ['referral', 'display', 'referral', 'email'],
#  ['referral', 'referral'],
#  ['referral', 'social', 'referral', 'email'],
#  ['display', 'social', 'email'],
#  ['email', 'referral', 'display', 'referral'],
#  ['email', 'referral', 'display'],
#  ['email'],
#  ['email', 'display', 'referral'],
#  ['referral', 'email', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['email', 'social', 'display', 'referral', 'referral'],
#  ['email'],
#  ['display', 'paid_search', 'referral', 'email'],
#  ['referral', 'display', 'email'],
#  ['paid_search', 'referral', 'display', 'email'],
#  ['referral', 'referral'],
#  ['referral', 'email', 'email'],
#  ['email', 'referral', 'social'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'referral', 'email', 'email'],
#  ['email'],
#  ['referral', 'email'],
#  ['referral', 'display'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'email'],
#  ['email'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'email', 'email', 'display', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['display', 'referral', 'email'],
#  ['email'],
#  ['email', 'referral', 'display'],
#  ['display', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['social', 'display', 'email'],
#  ['email', 'referral', 'referral', 'referral', 'display'],
#  ['referral', 'organic_search', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email'],
#  ['email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral'],
#  ['email', 'referral', 'referral'],
#  ['email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['social', 'referral', 'referral', 'email'],
#  ['social', 'referral', 'email', 'social', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'social', 'email'],
#  ['referral', 'referral', 'email'],
#  ['display', 'display', 'email'],
#  ['referral', 'email'],
#  ['email', 'referral', 'email'],
#  ['email', 'referral'],
#  ['email'],
#  ['referral', 'display', 'email'],
#  ['referral', 'referral', 'referral', 'social', 'email'],
#  ['referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['social', 'referral', 'email'],
#  ['email', 'referral', 'email'],
#  ['email', 'email', 'social'],
#  ['display', 'referral', 'email'],
#  ['referral', 'email'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['referral', 'referral'],
#  ['referral', 'social', 'email'],
#  ['referral', 'display', 'email'],
#  ['email', 'social'],
#  ['referral', 'email'],
#  ['email', 'referral', 'social', 'referral'],
#  ['email', 'referral', 'referral', 'display', 'email'],
#  ['referral', 'referral', 'email', 'email'],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'email'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'display', 'social'],
#  ['referral', 'display', 'email'],
#  ['social', 'email'],
#  ['display', 'email'],
#  ['display', 'email'],
#  ['email'],
#  ['paid_search', 'email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral', 'social', 'email'],
#  ['email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'social', 'email'],
#  ['referral', 'social', 'email'],
#  ['referral', 'email'],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['referral', 'display', 'email'],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['social', 'referral', 'email'],
#  ['email', 'referral', 'social'],
#  ['referral', 'referral', 'email', 'email'],
#  ['email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['email', 'referral'],
#  ['referral'],
#  ['referral', 'referral', 'email', 'email'],
#  ['email', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'social', 'email'],
#  ['email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['social', 'referral', 'email'],
#  ['paid_search'],
#  ['email', 'display'],
#  ['email', 'referral', 'referral', 'email', 'referral'],
#  ['social', 'referral', 'paid_search', 'email'],
#  ['display', 'email', 'email'],
#  ['email', 'social', 'referral', 'referral'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'social', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'paid_search', 'referral'],
#  ['referral', 'social', 'display', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'social', 'email'],
#  ['email', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'paid_search'],
#  ['email', 'referral', 'display', 'referral'],
#  ['email', 'referral'],
#  ['email', 'referral', 'display', 'email'],
#  ['referral', 'referral'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['social', 'display', 'email'],
#  ['referral', 'display', 'referral', 'email'],
#  ['social', 'referral', 'email'],
#  ['display', 'email'],
#  ['email', 'display'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'email', 'email'],
#  ['email', 'referral'],
#  ['referral', 'email'],
#  ['social', 'referral'],
#  ['social', 'email'],
#  ['referral', 'paid_search', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'display'],
#  ['display', 'referral', 'email'],
#  ['email', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral'],
#  ['display'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'email'],
#  ['paid_search', 'referral', 'email'],
#  ['email', 'referral', 'email'],
#  ['email', 'referral', 'email'],
#  ['paid_search', 'social', 'referral', 'email'],
#  ['referral', 'paid_search', 'referral', 'email'],
#  ['email'],
#  ['email', 'display', 'email', 'referral', 'social'],
#  ['email', 'referral', 'display'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'organic_search', 'referral', 'email'],
#  ['display', 'display', 'email', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'display', 'referral'],
#  ['referral', 'referral', 'paid_search', 'email'],
#  ['email', 'referral', 'organic_search', 'referral', 'display'],
#  ['referral', 'email'],
#  ['email', 'referral', 'email', 'referral'],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['display', 'referral', 'email'],
#  ['social', 'display', 'referral', 'email'],
#  ['email', 'referral'],
#  ['email', 'referral'],
#  ['referral', 'social', 'email'],
#  ['email'],
#  ['email', 'referral', 'social', 'display'],
#  ['social', 'email', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'email'],
#  ['email', 'social', 'email'],
#  ['email'],
#  ['display', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'email', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['email'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'social', 'social', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email'],
#  ['email'],
#  ['referral', 'social', 'email'],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'email'],
#  ['referral', 'social', 'email'],
#  ['referral', 'referral'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['referral', 'display', 'referral', 'display', 'email'],
#  ['display', 'referral', 'display', 'referral', 'email'],
#  ['referral', 'email'],
#  ['referral', 'email', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['referral', 'email'],
#  ['email', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral'],
#  ['social', 'referral', 'email'],
#  ['email'],
#  ['email'],
#  ['email', 'email'],
#  ['email', 'referral', 'email'],
#  ['display', 'social', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'email', 'email'],
#  ['email'],
#  ['referral', 'social', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['social', 'email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'display', 'referral', 'email'],
#  ['referral', 'email'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['display', 'referral', 'email'],
#  ['display', 'referral', 'email'],
#  ['email'],
#  ['referral', 'email', 'email'],
#  ['email', 'referral', 'email'],
#  ['referral', 'email'],
#  ['social', 'referral', 'referral', 'email'],
#  ['email'],
#  ['display', 'referral', 'email'],
#  ['email', 'referral'],
#  ['email', 'referral'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['email'],
#  ['referral', 'email', 'email', 'email'],
#  ['social', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'email', 'referral'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'display', 'social'],
#  ['referral', 'referral', 'email'],
#  ['email', 'display'],
#  ['email', 'referral', 'social', 'referral'],
#  ['social', 'referral', 'email', 'email'],
#  ['referral', 'display', 'email'],
#  ['referral', 'referral', 'email'],
#  ['social', 'email'],
#  ['referral', 'display', 'referral', 'email'],
#  ['referral', 'email'],
#  ['referral', 'display', 'email'],
#  ['referral', 'email'],
#  ['referral', 'social', 'referral', 'referral', 'email'],
#  ['email', 'social', 'email'],
#  ['referral', 'email'],
#  ['social', 'email', 'email'],
#  ['social', 'email'],
#  ['email', 'email', 'email'],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['referral', 'display', 'email'],
#  ['social', 'display', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'social', 'display'],
#  ['email', 'paid_search'],
#  ['referral', 'email', 'display', 'email'],
#  ['email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'email', 'social', 'email'],
#  ['email'],
#  ['referral', 'display', 'referral', 'email'],
#  ['referral', 'email', 'social', 'email'],
#  ['social'],
#  ['referral', 'referral', 'social'],
#  ['direct', 'referral', 'social'],
#  ['referral', 'social'],
#  ['email', 'referral', 'social'],
#  ['email', 'referral', 'paid_search', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'display', 'social'],
#  ['social', 'referral'],
#  ['display', 'social'],
#  ['referral', 'social', 'social'],
#  ['referral', 'display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'email', 'social'],
#  ['social'],
#  ['social'],
#  ['social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['display', 'display'],
#  ['social', 'display', 'social', 'referral'],
#  ['referral', 'social'],
#  ['social', 'email', 'display'],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['social', 'referral'],
#  ['social', 'social', 'referral'],
#  ['referral', 'display', 'social'],
#  ['social', 'social', 'display', 'display', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['display', 'email'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'display', 'referral', 'social'],
#  ['social', 'referral', 'display'],
#  ['social'],
#  ['referral', 'social'],
#  ['social', 'referral'],
#  ['social', 'referral', 'social', 'referral', 'social'],
#  ['social', 'email', 'referral'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'display'],
#  ['display', 'referral'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'display', 'social', 'referral', 'paid_search'],
#  ['referral', 'social', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'social', 'social'],
#  ['referral', 'display', 'referral', 'referral', 'social'],
#  ['referral', 'referral'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'social', 'social'],
#  ['social', 'social'],
#  ['social'],
#  ['social', 'email'],
#  ['social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'paid_search', 'referral', 'social'],
#  ['social', 'referral', 'social', 'display', 'email'],
#  ['social', 'referral', 'referral'],
#  ['social', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral', 'email', 'social'],
#  ['social', 'display', 'email'],
#  ['display', 'referral', 'social'],
#  ['referral', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['display', 'social'],
#  ['display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['email', 'referral'],
#  ['referral', 'social', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['social'],
#  ['social', 'referral', 'referral', 'display', 'social'],
#  ['social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'paid_search', 'social'],
#  ['referral', 'referral', 'social', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'email', 'referral'],
#  ['referral', 'email', 'display', 'display', 'social'],
#  ['social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social'],
#  ['display', 'email', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'display', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social', 'social'],
#  ['social'],
#  ['display', 'referral'],
#  ['social', 'referral', 'referral', 'paid_search'],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'display'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['display', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['social', 'referral', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'paid_search', 'social'],
#  ['referral', 'referral', 'social', 'social'],
#  ['paid_search', 'display', 'referral'],
#  ['social', 'referral'],
#  ['social', 'display'],
#  ['social', 'email', 'referral', 'referral', 'referral'],
#  ['email', 'referral', 'social'],
#  ['social'],
#  ['social', 'referral', 'referral'],
#  ['social', 'paid_search', 'referral', 'referral'],
#  ['display', 'display', 'referral', 'social'],
#  ['social'],
#  ['referral', 'referral'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['display', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['social', 'social', 'social'],
#  ['referral', 'social', 'display', 'social'],
#  ['social', 'referral', 'referral'],
#  ['social'],
#  ['display'],
#  ['referral', 'referral', 'display', 'social'],
#  ['social', 'referral', 'referral'],
#  ['social'],
#  ['social'],
#  ['display', 'referral', 'social', 'social'],
#  ['social'],
#  ['referral', 'social', 'social'],
#  ['email', 'referral', 'display', 'referral', 'social'],
#  ['social', 'referral', 'social'],
#  ['social', 'paid_search'],
#  ['referral', 'social'],
#  ['referral', 'social', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'display', 'social'],
#  ['social', 'referral', 'referral'],
#  ['social'],
#  ['social'],
#  ['social', 'display', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'email', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral'],
#  ['referral', 'display', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['email', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'social', 'referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'social', 'social'],
#  ['social', 'display', 'referral'],
#  ['social', 'display', 'referral', 'social'],
#  ['social'],
#  ['social', 'display'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['email', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'social'],
#  ['display', 'social', 'social'],
#  ['social', 'referral', 'email'],
#  ['referral', 'social', 'referral', 'display', 'social'],
#  ['referral', 'paid_search', 'social'],
#  ['display', 'referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'email'],
#  ['email', 'referral', 'social'],
#  ['social', 'social', 'referral', 'referral'],
#  ['social', 'email', 'referral'],
#  ['social', 'referral'],
#  ['email', 'referral', 'social'],
#  ['referral', 'display', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['email', 'display', 'referral', 'social'],
#  ['social', 'referral'],
#  ['social', 'referral', 'display'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'social', 'referral'],
#  ['referral', 'social', 'social'],
#  ['referral', 'referral', 'social'],
#  ['display', 'social', 'social'],
#  ['display', 'email'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'social'],
#  ['referral', 'display'],
#  ['social'],
#  ['display', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'email', 'email', 'referral'],
#  ['social', 'social', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['email', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['paid_search', 'social', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social'],
#  ['social', 'referral', 'email'],
#  ['referral', 'referral', 'social'],
#  ['referral'],
#  ['social'],
#  ['referral', 'social'],
#  ['referral', 'referral'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral', 'email', 'paid_search'],
#  ['referral', 'social'],
#  ['referral'],
#  ['social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'social', 'referral'],
#  ['referral', 'social', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'social'],
#  ['display', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'display'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['email', 'social'],
#  ['referral', 'social'],
#  ['social'],
#  ['referral', 'social'],
#  ['social', 'email', 'referral'],
#  ['social', 'referral', 'email', 'referral'],
#  ['referral', 'referral', 'display', 'social'],
#  ['display', 'social', 'social'],
#  ['email', 'social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['social', 'social', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral'],
#  ['social'],
#  ['social'],
#  ['social', 'referral', 'referral', 'social'],
#  ['social'],
#  ['social', 'referral', 'referral'],
#  ['display', 'display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'email'],
#  ['display', 'social'],
#  ['display', 'referral', 'email', 'social'],
#  ['referral', 'social'],
#  ['referral', 'display', 'social'],
#  ['social', 'social', 'referral', 'email', 'referral'],
#  ['social'],
#  ['social', 'referral', 'display'],
#  ['social'],
#  ['referral', 'social', 'referral', 'social'],
#  ['referral', 'email', 'referral', 'social'],
#  ['referral', 'organic_search'],
#  ['referral', 'referral'],
#  ['referral', 'display'],
#  ['social', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['social', 'email', 'display', 'referral'],
#  ['email', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social'],
#  ['social'],
#  ['social', 'display'],
#  ['social'],
#  ['referral', 'referral', 'referral', 'social', 'social'],
#  ['social'],
#  ['social', 'referral', 'referral'],
#  ['paid_search', 'social'],
#  ['social'],
#  ['referral'],
#  ['referral', 'referral', 'social', 'social', 'social'],
#  ['social', 'display', 'referral', 'referral'],
#  ['referral', 'social'],
#  ['display', 'social', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['social', 'referral', 'display', 'referral', 'paid_search'],
#  ['social'],
#  ['referral', 'social'],
#  ['referral', 'email', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'paid_search', 'social'],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'social'],
#  ['social', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'social', 'social'],
#  ['social', 'display', 'social'],
#  ['social', 'referral', 'social', 'referral'],
#  ['social'],
#  ['social', 'email', 'referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'social', 'social'],
#  ['referral', 'social'],
#  ['social'],
#  ['social', 'referral', 'referral'],
#  ['display', 'referral', 'social'],
#  ['social'],
#  ['display', 'referral', 'social'],
#  ['email', 'paid_search', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'email'],
#  ['social', 'display', 'display'],
#  ['social', 'referral', 'social', 'referral'],
#  ['referral', 'email', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social'],
#  ['email', 'referral', 'social'],
#  ['referral', 'social', 'social'],
#  ['social', 'email', 'social'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['organic_search', 'display', 'referral', 'social'],
#  ['social'],
#  ['display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'display', 'social'],
#  ['social', 'referral', 'social'],
#  ['social', 'referral', 'social', 'display', 'social'],
#  ['social', 'social', 'referral'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['social', 'paid_search', 'referral'],
#  ['social', 'referral', 'display'],
#  ['referral', 'social', 'email', 'social'],
#  ['referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral'],
#  ['referral', 'referral', 'social'],
#  ['email', 'social', 'referral', 'social'],
#  ['referral', 'email', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'social'],
#  ['referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'email', 'social'],
#  ['referral', 'social'],
#  ['referral', 'social', 'referral', 'social'],
#  ['social', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['social', 'display', 'paid_search', 'referral'],
#  ['social', 'paid_search', 'referral', 'referral'],
#  ['social', 'email', 'referral', 'direct', 'referral'],
#  ['email', 'referral', 'social'],
#  ['display', 'referral', 'social'],
#  ['referral', 'social', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['social', 'social', 'referral', 'social'],
#  ['referral', 'paid_search', 'referral', 'social', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'email'],
#  ['social', 'referral', 'social'],
#  ['social', 'email', 'referral'],
#  ['social', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'display', 'display', 'social'],
#  ['social'],
#  ['social'],
#  ['referral', 'referral', 'social'],
#  ['paid_search', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'email', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'email', 'referral', 'social'],
#  ['display', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'display', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['display', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'display'],
#  ['social', 'referral', 'referral'],
#  ['paid_search', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'display', 'social'],
#  ['social', 'social'],
#  ['social', 'referral'],
#  ['paid_search', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'social', 'social'],
#  ['social', 'social'],
#  ['social'],
#  ['social', 'referral', 'social'],
#  ['social', 'referral', 'social'],
#  ['social', 'display', 'referral'],
#  ['social'],
#  ['social', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'display', 'social', 'social'],
#  ['social', 'display', 'referral', 'referral'],
#  ['referral', 'paid_search', 'referral', 'social'],
#  ['social', 'social'],
#  ['social'],
#  ['referral', 'display', 'social'],
#  ['email', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'display', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'social', 'referral', 'referral'],
#  ['display', 'social', 'social'],
#  ['display', 'social'],
#  ['referral'],
#  ['display', 'social'],
#  ['social', 'referral', 'paid_search', 'referral', 'referral'],
#  ['social', 'social', 'social'],
#  ['referral', 'referral', 'social', 'social', 'social'],
#  ['referral', 'social'],
#  ['social', 'social', 'referral'],
#  ['social'],
#  ['referral', 'referral', 'social'],
#  ['display', 'referral', 'social'],
#  ['social', 'social', 'social'],
#  ['referral'],
#  ['referral', 'email', 'social'],
#  ['email', 'display', 'paid_search', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'email', 'social'],
#  ['social', 'referral', 'display'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'email', 'referral', 'social'],
#  ['display', 'referral', 'social'],
#  ['referral', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['paid_search', 'referral', 'social'],
#  ['referral', 'social', 'social'],
#  ['social', 'display'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'email', 'email', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral', 'paid_search', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'social', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'display', 'referral'],
#  ['referral', 'social', 'display', 'social'],
#  ['social', 'email', 'referral', 'referral'],
#  ['social'],
#  ['social', 'referral'],
#  ['social', 'social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social'],
#  ['social', 'display', 'referral', 'display'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral'],
#  ['social'],
#  ['referral', 'referral', 'display', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'social', 'referral', 'social'],
#  ['social'],
#  ['referral'],
#  ['paid_search', 'referral', 'referral', 'social'],
#  ['social', 'social', 'referral'],
#  ['referral', 'referral'],
#  ['referral', 'display', 'referral', 'social', 'social'],
#  ['display', 'display'],
#  ['display', 'social'],
#  ['social', 'social'],
#  ['social', 'referral', 'referral'],
#  ['display', 'social'],
#  ['social'],
#  ['social', 'display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'email', 'referral'],
#  ['social', 'referral', 'social'],
#  ['display', 'social'],
#  ['social', 'referral', 'email', 'referral'],
#  ['social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'social', 'referral', 'social'],
#  ['display', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'social'],
#  ['organic_search', 'referral', 'social'],
#  ['email', 'referral', 'email', 'social'],
#  ['social', 'social', 'referral'],
#  ['social', 'social', 'email', 'email', 'referral'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'email', 'referral', 'email', 'social'],
#  ['social', 'referral', 'referral'],
#  ['social', 'referral', 'paid_search', 'email', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'email', 'referral', 'referral', 'email'],
#  ['display', 'social'],
#  ['referral', 'social'],
#  ['display', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['social'],
#  ['social'],
#  ['social', 'social', 'referral'],
#  ['referral', 'social', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'social', 'social'],
#  ['referral', 'referral', 'display', 'social'],
#  ['display', 'display', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'display'],
#  ['display', 'paid_search', 'social'],
#  ['referral', 'social', 'social', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social', 'social'],
#  ['social', 'referral'],
#  ['display', 'referral', 'paid_search', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'display', 'referral', 'social'],
#  ['referral', 'social', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['display'],
#  ['social', 'referral', 'display', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['display', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'social'],
#  ['referral', 'social'],
#  ['display', 'referral', 'social'],
#  ['email', 'referral'],
#  ['social'],
#  ['social', 'referral', 'referral', 'social'],
#  ['referral', 'display', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['paid_search', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'paid_search'],
#  ['referral', 'referral', 'email', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'social', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social', 'social'],
#  ['display', 'display', 'referral', 'referral'],
#  ['social'],
#  ['display', 'referral', 'social'],
#  ['social', 'display', 'social'],
#  ['display', 'email', 'display'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'display'],
#  ['social', 'display', 'social'],
#  ['social', 'social', 'referral', 'social'],
#  ['referral', 'email', 'social'],
#  ['display', 'email', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral'],
#  ['social', 'display', 'referral'],
#  ['email', 'social'],
#  ['referral', 'social'],
#  ['referral', 'display', 'display'],
#  ['referral', 'social'],
#  ['referral', 'email', 'email'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'display', 'social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'display', 'social', 'social'],
#  ['social', 'social', 'referral'],
#  ['social', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral'],
#  ...]

# %%
counts = dict()



for i in range(len(touch_list_convert2)):
    if len(touch_list_convert2[i]) == 2:
        for j in range(len(touch_list_convert2[i])):
            counts[touch_list_convert2[i][j]] = counts.get(touch_list_convert2[i][j],0)+0.5
    elif len(touch_list_convert2[i]) == 3:
        for j in range(len(touch_list_convert2[i])):
            counts[touch_list_convert2[i][j]] = counts.get(touch_list_convert2[i][j],0)+ 1/3
    elif len(touch_list_convert2[i]) == 4:
        for j in range(len(touch_list_convert2[i])):
            counts[touch_list_convert2[i][j]] = counts.get(touch_list_convert2[i][j],0)+ 1/4
    elif len(touch_list_convert2[i]) == 5:
        for j in range(len(touch_list_convert2[i])):
            counts[touch_list_convert2[i][j]] = counts.get(touch_list_convert2[i][j],0)+ 1/5
    else:
        for j in range(len(touch_list_convert2[i])):
            counts[touch_list_convert2[i][j]] = counts.get(touch_list_convert2[i][j],0)+ 1

counts
# Out:
# {'display': 724.0833333333404,
#  'referral': 2656.683333333344,
#  'email': 442.51666666666245,
#  'social': 822.3666666666782,
#  'paid_search': 237.81666666666717,
#  'organic_search': 6.466666666666666,
#  'direct': 2.0666666666666664}

# %%
convert_tier2 = pd.DataFrame(list(counts.items()),columns = ['channel','converts'])
convert_tier2
# Out:
#           channel     converts
# 0         display   724.083333
# 1        referral  2656.683333
# 2           email   442.516667
# 3          social   822.366667
# 4     paid_search   237.816667
# 5  organic_search     6.466667
# 6          direct     2.066667

# %%
convert3_combined = convert3.iloc[:,1:6]
convert3_combined['combined']= convert3_combined.values.tolist()
convert3_combined.drop(convert3_combined.iloc[:, 0:5], inplace=True, axis=1)
convert3_combined
# Out:
#                                                 combined
# 34062         [referral, referral, referral, email, nan]
# 34063                   [email, email, social, nan, nan]
# 34064              [referral, referral, email, nan, nan]
# 34065              [email, referral, referral, nan, nan]
# 34066              [email, referral, referral, nan, nan]
# ...                                                  ...
# 60648           [referral, referral, referral, nan, nan]
# 60649                 [display, referral, nan, nan, nan]
# 68103  [organic_search, referral, paid_search, nan, nan]
# 68104           [organic_search, display, nan, nan, nan]
# 68117                       [direct, nan, nan, nan, nan]
#
# [6063 rows x 1 columns]

# %%
touch_list_convert3 = convert3_combined['combined'].dropna().tolist()
touch_list_convert3
# Out:
# [['referral', 'referral', 'referral', 'email', nan],
#  ['email', 'email', 'social', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', nan, nan],
#  ['referral', 'display', 'referral', 'referral', 'email'],
#  ['referral', 'paid_search', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'referral', 'paid_search', 'email'],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'display', nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'display', 'referral', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['display', 'display', 'email', nan, nan],
#  ['display', 'social', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', 'email', nan],
#  ['referral', 'paid_search', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['display', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'social', 'referral', 'email', nan],
#  ['referral', nan, nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', 'referral', 'email'],
#  ['display', 'referral', 'email', nan, nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['email', nan, nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', 'paid_search', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', 'referral', 'display', nan, nan],
#  ['email', 'referral', 'display', 'referral', nan],
#  ['email', 'referral', 'email', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['display', 'referral', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'display', 'display', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['social', 'email', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'display', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'email', 'social', nan, nan],
#  ['display', 'referral', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'social', 'referral', nan, nan],
#  ['email', 'direct', nan, nan, nan],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['email', 'social', nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['email', 'social', 'email', nan, nan],
#  ['referral', 'social', 'email', nan, nan],
#  ['display', 'referral', 'referral', 'display', 'email'],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['social', 'display', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['display', 'email', 'referral', 'referral', nan],
#  ['email', 'paid_search', 'referral', nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['email', 'referral', 'referral', 'display', nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['email', 'referral', 'referral', 'display', nan],
#  ['paid_search', 'referral', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['email', 'referral', 'display', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['referral', 'referral', 'referral', 'social', 'email'],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'email', 'social', 'referral', 'email'],
#  ['referral', 'display', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'social', 'referral', 'referral', nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'social', 'referral', 'referral', 'referral'],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'display', 'referral', nan, nan],
#  ['display', 'referral', 'referral', 'email', nan],
#  ['referral', 'email', nan, nan, nan],
#  ['paid_search', 'email', nan, nan, nan],
#  ['referral', 'referral', 'display', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'paid_search', 'social', 'email', nan],
#  ['email', 'social', 'referral', 'referral', nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['display', 'referral', nan, nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['display', 'referral', 'referral', 'email', nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'email', 'referral', 'email', nan],
#  ['email', 'display', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'paid_search', 'email', nan, nan],
#  ['email', 'display', 'display', 'referral', 'email'],
#  ['referral', 'display', 'referral', 'referral', 'email'],
#  ['referral', 'display', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'display', 'referral', nan, nan],
#  ['referral', 'social', 'referral', nan, nan],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['display', 'referral', 'email', nan, nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['display', 'referral', 'email', nan, nan],
#  ['referral', 'social', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'display', 'referral', nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['referral', 'referral', 'display', 'email', nan],
#  ['email', 'social', 'display', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['display', 'referral', nan, nan, nan],
#  ['email', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'social', 'paid_search', 'referral', nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['referral', 'referral', 'referral', 'social', 'email'],
#  ['referral', 'referral', 'referral', nan, nan],
#  ['referral', 'display', nan, nan, nan],
#  ['email', 'email', 'referral', 'email', nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['display', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'display', 'referral', 'referral', nan],
#  ['referral', 'display', 'display', 'email', nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'social', 'referral', nan, nan],
#  ['email', 'display', 'referral', nan, nan],
#  ['referral', 'referral', 'display', 'email', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'paid_search', nan, nan, nan],
#  ['social', 'referral', 'email', 'referral', 'email'],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['paid_search', 'referral', 'referral', 'email', nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'paid_search', 'referral', 'email', nan],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['email', 'referral', 'display', nan, nan],
#  ['email', 'social', 'social', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['display', 'display', 'referral', 'email', nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', 'display', 'referral', 'referral'],
#  ['email', 'referral', 'social', nan, nan],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['email', 'display', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'paid_search', nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', 'display', nan, nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'email', 'display', 'email', nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['referral', 'social', 'email', nan, nan],
#  ['email', 'referral', 'email', 'social', nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['display', 'social', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['email', 'referral', 'social', 'email', 'email'],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'email', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'display', 'email'],
#  ['email', 'referral', 'referral', 'social', nan],
#  ['display', 'referral', 'referral', 'email', nan],
#  ['referral', 'paid_search', 'social', 'referral', 'email'],
#  ['referral', 'referral', 'display', 'email', nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'paid_search', 'email', nan, nan],
#  ['email', 'referral', 'display', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['paid_search', 'referral', 'email', nan, nan],
#  ['referral', 'display', 'email', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['referral', 'display', 'referral', 'email', nan],
#  ['referral', 'email', 'social', 'email', 'email'],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'referral', 'referral', 'display'],
#  ['email', 'referral', 'display', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'paid_search', 'email', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', 'referral', 'email'],
#  ['social', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'display', nan, nan],
#  ['email', 'paid_search', 'referral', 'referral', nan],
#  ['social', 'email', nan, nan, nan],
#  ['referral', 'display', 'referral', 'email', nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['referral', 'social', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'email', nan, nan, nan],
#  ['display', 'email', nan, nan, nan],
#  ['referral', 'display', 'referral', 'social', 'email'],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'social', 'email', nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['email', 'social', 'referral', nan, nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', 'email', nan],
#  ['display', 'referral', 'referral', nan, nan],
#  ['display', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'email', nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'paid_search', 'email', nan, nan],
#  ['email', 'display', 'referral', 'email', nan],
#  ['referral', 'social', 'email', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['display', 'referral', 'email', nan, nan],
#  ['email', 'referral', 'email', 'social', nan],
#  ['email', nan, nan, nan, nan],
#  ['email', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'display', 'email', nan],
#  ['email', 'referral', 'email', nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['email', 'referral', 'referral', 'referral', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'email', 'social', nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'social', nan, nan, nan],
#  ['email', 'referral', 'referral', 'social', nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['referral', 'email', 'referral', 'social', nan],
#  ['social', 'email', 'email', nan, nan],
#  ['social', 'display', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'social', 'referral'],
#  ['social', nan, nan, nan, nan],
#  ['social', 'email', 'social', nan, nan],
#  ['referral', 'display', 'display', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'email', 'social', nan],
#  ['referral', 'email', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'email', 'referral', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['paid_search', 'display', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['display', 'display', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'referral', 'email', 'social'],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'social', 'email', 'social'],
#  ['display', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', nan],
#  ['social', 'referral', 'referral', 'display', nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'display', 'referral', 'referral', nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'email', 'email', 'social', nan],
#  ['referral', 'referral', 'paid_search', 'social', nan],
#  ['referral', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['display', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['social', 'social', 'referral', 'social', nan],
#  ['referral', 'social', 'email', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['social', 'referral', 'paid_search', nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['social', 'referral', 'display', nan, nan],
#  ['social', 'referral', 'display', nan, nan],
#  ['social', 'referral', 'referral', 'paid_search', nan],
#  ['display', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'display', nan, nan, nan],
#  ['social', 'display', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'referral', 'social', 'referral', nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'social', 'referral', 'social', nan],
#  ['display', 'social', nan, nan, nan],
#  ['email', 'referral', 'referral', 'social', 'social'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['email', 'referral', 'referral', 'social', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'social', 'social', nan, nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['social', 'display', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'email', 'referral', nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['paid_search', 'referral', 'referral', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'social', 'referral', 'referral', nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'social', 'social', 'email'],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['referral', 'display', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'social', 'social', nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'display', 'referral', 'referral', 'social'],
#  ['referral', 'email', 'referral', 'social', nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['display', nan, nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'email', 'display', 'referral', 'social'],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', 'social'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['display', 'social', 'email', 'social', nan],
#  ['display', 'referral', 'referral', 'display', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['email', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'display', 'email', 'social', nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', 'referral', 'social', nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'paid_search', 'referral', 'referral', 'social'],
#  ['social', 'social', 'social', nan, nan],
#  ['referral', 'social', 'referral', 'referral', 'social'],
#  ['social', 'email', 'referral', 'referral', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['social', 'referral', 'display', nan, nan],
#  ['referral', 'referral', 'social', 'social', nan],
#  ['referral', 'display', 'referral', 'social', nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'social', 'email', 'email', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'display', 'referral', 'social'],
#  ['referral', 'referral', 'social', 'social', nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['social', 'social', 'referral', 'referral', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'email', 'referral', nan, nan],
#  ['social', 'email', 'referral', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', nan, nan, nan, nan],
#  ['social', 'display', nan, nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', 'social', 'social', nan, nan],
#  ['social', 'display', 'referral', nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['display', 'display', 'email', 'social', nan],
#  ['display', 'referral', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['social', 'referral', 'display', 'referral', 'referral'],
#  ['display', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['display', nan, nan, nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'social', nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'email', 'social', 'social', nan],
#  ['referral', 'referral', 'paid_search', 'social', nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['display', 'social', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'display', 'social', 'referral', 'social'],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['email', 'social', nan, nan, nan],
#  ['paid_search', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['email', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'paid_search', 'social', nan, nan],
#  ['referral', 'referral', 'paid_search', 'social', 'social'],
#  ['referral', 'referral', 'social', 'referral', 'social'],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', 'referral', 'referral', 'social'],
#  ['social', 'social', 'social', nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'display', nan, nan],
#  ['referral', 'social', 'referral', 'referral', 'social'],
#  ['referral', 'referral', nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['email', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['email', 'display', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'paid_search', nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'display', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'display', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'display', 'display', 'referral', nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['social', 'email', 'referral', 'referral', nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', 'social', 'email', 'social', nan],
#  ['social', 'referral', 'referral', 'social', 'social'],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['social', 'referral', 'referral', 'display', nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['paid_search', 'social', nan, nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', 'referral', 'social', 'email', 'email'],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['display', 'social', nan, nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['display', 'referral', 'referral', 'social', nan],
#  ['social', 'display', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'email', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'email', 'display', 'social'],
#  ['social', 'referral', nan, nan, nan],
#  ['display', 'display', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'referral', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', 'display', nan],
#  ['social', 'social', 'display', 'display', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['display', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'email', nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['paid_search', 'display', 'referral', 'social', nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['referral', 'email', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', nan, nan],
#  ['referral', 'paid_search', 'social', nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['display', 'referral', nan, nan, nan],
#  ['display', 'social', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['display', 'referral', 'display', 'email', 'social'],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'display', 'social'],
#  ['display', 'email', nan, nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['display', 'referral', 'referral', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'display', 'referral', nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'display', nan, nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['paid_search', 'social', 'social', nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', 'referral', 'referral', nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'email', 'paid_search', 'referral'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['display', 'email', 'referral', 'social', nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['paid_search', 'display', 'social', nan, nan],
#  ['social', 'referral', 'display', nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', 'social'],
#  ['social', 'referral', 'email', 'social', nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'display', 'display', 'social', nan],
#  ['social', 'referral', 'display', 'social', 'display'],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['display', 'display', nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['referral', 'referral', 'email', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'email', 'social', nan, nan],
#  ['social', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['display', 'email', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['social', 'display', 'referral', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'paid_search', nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['social', 'display', 'email', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'email', 'referral', nan, nan],
#  ['display', 'referral', 'referral', 'social', nan],
#  ['email', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'direct', 'referral', 'display', nan],
#  ['display', 'referral', 'referral', 'email', 'social'],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'email', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'social', 'referral', 'referral', 'display'],
#  ['social', 'referral', 'social', nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'display', 'social', 'social', nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', nan, nan, nan, nan],
#  ['email', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['paid_search', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'display', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'email', 'referral', 'referral'],
#  ['social', 'paid_search', nan, nan, nan],
#  ['social', 'display', 'email', nan, nan],
#  ['social', 'email', 'display', nan, nan],
#  ['referral', 'display', 'email', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['display', nan, nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['email', 'social', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'referral', nan, nan],
#  ['social', 'referral', 'social', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['email', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['social', 'paid_search', 'referral', nan, nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['paid_search', 'referral', 'referral', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'social', 'email', 'paid_search', 'social'],
#  ['referral', 'social', 'referral', 'referral', 'social'],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['social', 'email', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'display', nan, nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['paid_search', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'paid_search', nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['display', 'referral', 'referral', 'social', nan],
#  ['social', 'display', 'referral', 'referral', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['paid_search', 'paid_search', 'referral', 'referral', 'social'],
#  ['social', 'email', 'display', nan, nan],
#  ['email', 'referral', nan, nan, nan],
#  ['social', 'social', 'referral', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'organic_search', 'referral', 'social', nan],
#  ['display', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'display', 'email', 'social'],
#  ['social', 'display', 'referral', 'referral', nan],
#  ['referral', 'social', 'display', 'referral', 'social'],
#  ['social', 'referral', 'display', 'referral', nan],
#  ['referral', 'referral', 'referral', nan, nan],
#  ['display', 'referral', 'display', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'referral', 'display', 'social'],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', nan, nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', nan],
#  ['display', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'email', 'email', 'display', 'social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', 'display', 'display', 'display', 'social'],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['organic_search', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'display', 'referral', 'social', nan],
#  ['social', 'social', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'paid_search', 'social', nan, nan],
#  ['social', 'referral', 'display', nan, nan],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'social', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'social', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'paid_search', 'referral', 'social', nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['social', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'social', 'referral', nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'display', 'social', nan, nan],
#  ['social', 'social', 'social', nan, nan],
#  ['display', 'social', nan, nan, nan],
#  ['email', 'referral', 'referral', 'social', nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'paid_search', 'social', nan, nan],
#  ['social', 'email', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'display', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'social', 'email', 'display', nan],
#  ['display', 'referral', 'display', nan, nan],
#  ['referral', 'referral', 'social', 'social', nan],
#  ['social', 'social', 'social', nan, nan],
#  ['social', 'display', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', 'referral', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['display', 'social', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['paid_search', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'referral', nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['email', 'paid_search', 'display', 'social', nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'paid_search', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ['social', nan, nan, nan, nan],
#  ['referral', 'referral', 'display', 'social', 'social'],
#  ['display', 'display', nan, nan, nan],
#  ['referral', 'referral', 'referral', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['referral', 'referral', 'social', 'social', nan],
#  ['referral', 'referral', 'social', nan, nan],
#  ['social', 'referral', 'referral', 'display', nan],
#  ['social', nan, nan, nan, nan],
#  ['social', 'referral', 'referral', nan, nan],
#  ['referral', 'referral', nan, nan, nan],
#  ['referral', 'social', nan, nan, nan],
#  ...]

# %%
for i in range(len(touch_list_convert3)):
    touch_list_convert3[i] = [x for x in touch_list_convert3[i] if str(x) != 'nan']
touch_list_convert3
# Out:
# [['referral', 'referral', 'referral', 'email'],
#  ['email', 'email', 'social'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral', 'referral'],
#  ['email'],
#  ['email'],
#  ['email'],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral'],
#  ['referral', 'display', 'referral', 'referral', 'email'],
#  ['referral', 'paid_search', 'email'],
#  ['referral', 'email'],
#  ['referral', 'email'],
#  ['email', 'referral', 'referral', 'paid_search', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'display'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral', 'referral'],
#  ['email', 'display', 'referral'],
#  ['email', 'referral'],
#  ['display', 'display', 'email'],
#  ['display', 'social', 'email'],
#  ['email'],
#  ['referral', 'email'],
#  ['email', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'email'],
#  ['referral', 'paid_search', 'email'],
#  ['referral', 'email'],
#  ['email'],
#  ['email', 'referral', 'social'],
#  ['display', 'referral', 'email'],
#  ['email'],
#  ['email'],
#  ['referral', 'social', 'referral', 'email'],
#  ['referral'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'display', 'email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'display', 'email'],
#  ['referral', 'email'],
#  ['referral', 'email'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'email', 'referral', 'email'],
#  ['display', 'referral', 'email'],
#  ['referral', 'display', 'email'],
#  ['social', 'referral', 'email'],
#  ['email', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'display', 'email'],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['email'],
#  ['email'],
#  ['email', 'referral', 'paid_search'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral'],
#  ['email', 'referral', 'display'],
#  ['email', 'referral', 'display', 'referral'],
#  ['email', 'referral', 'email', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['display', 'referral', 'email'],
#  ['referral', 'email'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['email'],
#  ['email', 'display', 'display'],
#  ['email'],
#  ['referral', 'referral', 'email'],
#  ['email'],
#  ['email'],
#  ['email', 'referral'],
#  ['email', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['social', 'email'],
#  ['referral', 'email'],
#  ['email'],
#  ['email', 'display'],
#  ['email'],
#  ['referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'email'],
#  ['email', 'email', 'social'],
#  ['display', 'referral', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'social', 'referral'],
#  ['email', 'direct'],
#  ['social', 'referral', 'referral', 'email'],
#  ['email', 'social'],
#  ['referral'],
#  ['email', 'social', 'email'],
#  ['referral', 'social', 'email'],
#  ['display', 'referral', 'referral', 'display', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['email', 'referral'],
#  ['referral', 'email'],
#  ['referral', 'display', 'email'],
#  ['email'],
#  ['social', 'display', 'email'],
#  ['email'],
#  ['referral', 'email'],
#  ['referral', 'email'],
#  ['display', 'email', 'referral', 'referral'],
#  ['email', 'paid_search', 'referral'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['referral', 'email'],
#  ['referral'],
#  ['email', 'referral', 'referral', 'display'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'display'],
#  ['paid_search', 'referral', 'email'],
#  ['referral', 'email'],
#  ['social', 'email'],
#  ['referral', 'referral', 'email'],
#  ['social', 'email'],
#  ['email', 'referral', 'display', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'social', 'email'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['referral', 'referral'],
#  ['referral', 'email', 'social', 'referral', 'email'],
#  ['referral', 'display', 'email'],
#  ['email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'social', 'referral', 'referral'],
#  ['email'],
#  ['email', 'social', 'referral', 'referral', 'referral'],
#  ['email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'display', 'referral'],
#  ['display', 'referral', 'referral', 'email'],
#  ['referral', 'email'],
#  ['paid_search', 'email'],
#  ['referral', 'referral', 'display'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'paid_search', 'social', 'email'],
#  ['email', 'social', 'referral', 'referral'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['display', 'referral'],
#  ['social', 'email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['display', 'referral', 'referral', 'email'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email'],
#  ['referral', 'email'],
#  ['email', 'referral'],
#  ['referral', 'email'],
#  ['referral', 'email', 'referral', 'email'],
#  ['email', 'display'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'paid_search', 'email'],
#  ['email', 'display', 'display', 'referral', 'email'],
#  ['referral', 'display', 'referral', 'referral', 'email'],
#  ['referral', 'display', 'email'],
#  ['email'],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email'],
#  ['email', 'display', 'referral'],
#  ['referral', 'social', 'referral'],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['display', 'referral', 'email'],
#  ['social', 'referral', 'email'],
#  ['display', 'referral', 'email'],
#  ['referral', 'social', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'display', 'referral'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'display', 'email'],
#  ['email', 'social', 'display'],
#  ['referral', 'email'],
#  ['social', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'email'],
#  ['email'],
#  ['display', 'referral'],
#  ['email', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['email', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral'],
#  ['email'],
#  ['email', 'social', 'paid_search', 'referral'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'social', 'email'],
#  ['referral', 'referral', 'referral'],
#  ['referral', 'display'],
#  ['email', 'email', 'referral', 'email'],
#  ['referral', 'referral'],
#  ['display', 'referral', 'email'],
#  ['email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'display', 'referral', 'referral'],
#  ['referral', 'display', 'display', 'email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'social', 'referral'],
#  ['email', 'display', 'referral'],
#  ['referral', 'referral', 'display', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral'],
#  ['social', 'referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'paid_search'],
#  ['social', 'referral', 'email', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral'],
#  ['paid_search', 'referral', 'referral', 'email'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'email'],
#  ['email'],
#  ['referral', 'paid_search', 'referral', 'email'],
#  ['social', 'referral', 'referral', 'email'],
#  ['social', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'display'],
#  ['email', 'social', 'social'],
#  ['referral', 'email'],
#  ['social', 'email'],
#  ['referral', 'referral', 'email'],
#  ['display', 'display', 'referral', 'email'],
#  ['email', 'referral', 'social'],
#  ['email'],
#  ['referral', 'email'],
#  ['email'],
#  ['email', 'referral', 'display', 'referral', 'referral'],
#  ['email', 'referral', 'social'],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['email', 'display', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'display', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'paid_search'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral', 'display'],
#  ['referral', 'display', 'email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'email', 'display', 'email'],
#  ['social', 'referral', 'email'],
#  ['referral', 'social', 'email'],
#  ['email', 'referral', 'email', 'social'],
#  ['email', 'referral'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['display', 'social', 'email'],
#  ['email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['email', 'referral', 'social', 'email', 'email'],
#  ['email'],
#  ['referral', 'email', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'email'],
#  ['referral', 'referral', 'referral', 'display', 'email'],
#  ['email', 'referral', 'referral', 'social'],
#  ['display', 'referral', 'referral', 'email'],
#  ['referral', 'paid_search', 'social', 'referral', 'email'],
#  ['referral', 'referral', 'display', 'email'],
#  ['referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['email'],
#  ['referral', 'paid_search', 'email'],
#  ['email', 'referral', 'display'],
#  ['email'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['paid_search', 'referral', 'email'],
#  ['referral', 'display', 'email'],
#  ['referral', 'referral', 'email'],
#  ['email', 'referral'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['referral'],
#  ['referral', 'referral', 'referral', 'referral', 'email'],
#  ['referral', 'display', 'referral', 'email'],
#  ['referral', 'email', 'social', 'email', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'email'],
#  ['email', 'referral', 'referral', 'referral', 'display'],
#  ['email', 'referral', 'display'],
#  ['referral', 'email'],
#  ['social', 'referral', 'referral', 'email'],
#  ['social', 'referral'],
#  ['referral', 'paid_search', 'email'],
#  ['email'],
#  ['email'],
#  ['referral', 'referral', 'social', 'referral', 'email'],
#  ['social', 'referral', 'email'],
#  ['email', 'referral', 'display'],
#  ['email', 'paid_search', 'referral', 'referral'],
#  ['social', 'email'],
#  ['referral', 'display', 'referral', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['referral', 'social', 'email'],
#  ['referral', 'email'],
#  ['email', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'email'],
#  ['display', 'email'],
#  ['referral', 'display', 'referral', 'social', 'email'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'social', 'email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['email', 'social', 'referral'],
#  ['email', 'referral', 'social'],
#  ['email', 'referral'],
#  ['referral'],
#  ['social', 'referral', 'referral', 'email'],
#  ['display', 'referral', 'referral'],
#  ['display'],
#  ['referral', 'referral', 'referral', 'email'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'paid_search', 'email'],
#  ['email', 'display', 'referral', 'email'],
#  ['referral', 'social', 'email'],
#  ['email', 'referral'],
#  ['email', 'referral', 'referral'],
#  ['email', 'referral', 'referral'],
#  ['display', 'referral', 'email'],
#  ['email', 'referral', 'email', 'social'],
#  ['email'],
#  ['email', 'referral', 'referral'],
#  ['referral', 'referral', 'display', 'email'],
#  ['email', 'referral', 'email'],
#  ['referral', 'email'],
#  ['email', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'email', 'social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['email', 'referral', 'referral', 'social'],
#  ['email', 'referral', 'social'],
#  ['referral', 'email', 'referral', 'social'],
#  ['social', 'email', 'email'],
#  ['social', 'display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'social', 'referral'],
#  ['social'],
#  ['social', 'email', 'social'],
#  ['referral', 'display', 'display', 'social'],
#  ['social'],
#  ['social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'email', 'social'],
#  ['referral', 'email', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'email', 'referral'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral'],
#  ['referral', 'referral', 'social'],
#  ['paid_search', 'display'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['display', 'display', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'email', 'social'],
#  ['social', 'referral'],
#  ['referral', 'referral', 'social', 'email', 'social'],
#  ['display', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'display'],
#  ['social', 'referral', 'social'],
#  ['referral', 'social'],
#  ['display', 'social'],
#  ['social'],
#  ['referral', 'referral'],
#  ['social'],
#  ['social', 'referral', 'social'],
#  ['social', 'social'],
#  ['social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['social', 'display', 'referral', 'referral'],
#  ['social', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'email', 'email', 'social'],
#  ['referral', 'referral', 'paid_search', 'social'],
#  ['referral', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral'],
#  ['referral', 'referral', 'social'],
#  ['display', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['social', 'social', 'referral', 'social'],
#  ['referral', 'social', 'email', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'paid_search'],
#  ['email'],
#  ['social', 'referral', 'display'],
#  ['social', 'referral', 'display'],
#  ['social', 'referral', 'referral', 'paid_search'],
#  ['display', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social'],
#  ['social', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'display'],
#  ['social', 'display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['social', 'referral', 'social', 'referral'],
#  ['social', 'referral'],
#  ['referral', 'social', 'referral', 'social'],
#  ['display', 'social'],
#  ['email', 'referral', 'referral', 'social', 'social'],
#  ['referral', 'referral', 'social'],
#  ['email', 'referral', 'referral', 'social', 'social'],
#  ['social'],
#  ['social', 'referral', 'social'],
#  ['social', 'social', 'social'],
#  ['referral', 'email', 'social'],
#  ['referral', 'referral'],
#  ['referral', 'social'],
#  ['social', 'email'],
#  ['email', 'referral'],
#  ['social', 'display'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'email', 'referral'],
#  ['social', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['paid_search', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['social', 'social', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'social', 'social', 'email'],
#  ['social', 'referral', 'referral'],
#  ['social', 'social'],
#  ['referral', 'display', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'social'],
#  ['social'],
#  ['social', 'social', 'social'],
#  ['social', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral', 'social'],
#  ['referral', 'social', 'social'],
#  ['social', 'referral', 'social'],
#  ['referral', 'display', 'referral', 'referral', 'social'],
#  ['referral', 'email', 'referral', 'social'],
#  ['referral', 'email', 'social'],
#  ['social', 'social', 'referral'],
#  ['display'],
#  ['referral'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'email', 'display', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'referral', 'social', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'social'],
#  ['display', 'social', 'email', 'social'],
#  ['display', 'referral', 'referral', 'display', 'social'],
#  ['social'],
#  ['referral', 'social'],
#  ['email', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'display', 'email', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'paid_search', 'referral', 'referral', 'social'],
#  ['social', 'social', 'social'],
#  ['referral', 'social', 'referral', 'referral', 'social'],
#  ['social', 'email', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'display'],
#  ['referral', 'referral', 'social', 'social'],
#  ['referral', 'display', 'referral', 'social'],
#  ['social', 'social', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['social', 'social', 'email', 'email'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'display', 'referral', 'social'],
#  ['referral', 'referral', 'social', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['social'],
#  ['referral', 'referral', 'social', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['display', 'referral', 'social'],
#  ['social', 'social', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'email', 'referral'],
#  ['social', 'email', 'referral'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral'],
#  ['social', 'display'],
#  ['referral', 'social', 'social'],
#  ['social', 'social', 'social'],
#  ['social', 'display', 'referral'],
#  ['display', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['social'],
#  ['display', 'display', 'email', 'social'],
#  ['display', 'referral', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'display', 'social'],
#  ['social', 'referral', 'display', 'referral', 'referral'],
#  ['display'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['social'],
#  ['display'],
#  ['display', 'referral', 'social'],
#  ['social', 'social', 'referral'],
#  ['referral', 'social', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['referral', 'social'],
#  ['display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'email', 'social', 'social'],
#  ['referral', 'referral', 'paid_search', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['display', 'social', 'social'],
#  ['social', 'referral', 'referral'],
#  ['social'],
#  ['social'],
#  ['referral', 'display', 'social', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'referral'],
#  ['social', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['email', 'social'],
#  ['paid_search', 'social'],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['email', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'social'],
#  ['referral', 'paid_search', 'social'],
#  ['referral', 'referral', 'paid_search', 'social', 'social'],
#  ['referral', 'referral', 'social', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social', 'referral', 'referral', 'social'],
#  ['social', 'social', 'social'],
#  ['social', 'referral', 'social'],
#  ['social', 'referral', 'display'],
#  ['referral', 'social', 'referral', 'referral', 'social'],
#  ['referral', 'referral'],
#  ['social', 'referral', 'social'],
#  ['social'],
#  ['referral', 'social'],
#  ['referral', 'referral'],
#  ['email'],
#  ['social', 'referral', 'referral'],
#  ['email', 'display', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'email', 'social'],
#  ['referral', 'social', 'social'],
#  ['social', 'referral', 'referral', 'paid_search'],
#  ['referral', 'referral'],
#  ['referral', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'display', 'social'],
#  ['social'],
#  ['email', 'referral', 'social'],
#  ['social'],
#  ['social', 'display', 'display', 'referral'],
#  ['display', 'referral', 'social'],
#  ['social', 'email', 'referral', 'referral'],
#  ['referral', 'email', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral', 'social', 'email', 'social'],
#  ['social', 'referral', 'referral', 'social', 'social'],
#  ['referral', 'social', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['social', 'referral', 'email'],
#  ['social', 'referral', 'referral', 'display'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['email', 'referral', 'social'],
#  ['paid_search', 'social'],
#  ['email', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['social', 'referral', 'social', 'email', 'email'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'social', 'social'],
#  ['social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['display', 'social'],
#  ['referral', 'display', 'social'],
#  ['social', 'social'],
#  ['referral', 'display', 'social'],
#  ['social'],
#  ['social', 'referral', 'referral', 'social'],
#  ['display', 'referral', 'referral', 'social'],
#  ['social', 'display', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'social'],
#  ['display', 'social'],
#  ['social', 'referral'],
#  ['referral', 'email'],
#  ['social'],
#  ['referral', 'referral', 'email', 'display', 'social'],
#  ['social', 'referral'],
#  ['display', 'display', 'social'],
#  ['referral', 'social'],
#  ['display', 'referral', 'social'],
#  ['referral', 'referral', 'referral'],
#  ['social'],
#  ['social', 'referral', 'referral', 'display'],
#  ['social', 'social', 'display', 'display'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['display', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'email'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral', 'social', 'social'],
#  ['paid_search', 'display', 'referral', 'social'],
#  ['display', 'referral', 'social'],
#  ['referral', 'email', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral'],
#  ['referral', 'paid_search', 'social'],
#  ['social', 'referral', 'social'],
#  ['social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['display', 'referral'],
#  ['display', 'social', 'social'],
#  ['social', 'referral'],
#  ['social'],
#  ['referral'],
#  ['referral', 'social'],
#  ['referral', 'email', 'social'],
#  ['social', 'referral'],
#  ['display', 'referral', 'display', 'email', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'referral', 'display', 'social'],
#  ['display', 'email'],
#  ['display', 'referral', 'social'],
#  ['social', 'referral'],
#  ['display', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['email', 'referral', 'social'],
#  ['social', 'referral', 'display', 'referral'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'display'],
#  ['email', 'referral'],
#  ['paid_search', 'social', 'social'],
#  ['referral', 'social', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'email', 'paid_search', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['social'],
#  ['social', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['display', 'email', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['paid_search', 'display', 'social'],
#  ['social', 'referral', 'display'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['social'],
#  ['referral', 'referral', 'referral', 'social', 'social'],
#  ['social', 'referral', 'email', 'social'],
#  ['social', 'referral'],
#  ['social', 'social'],
#  ['social', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'social', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'display', 'display', 'social'],
#  ['social', 'referral', 'display', 'social', 'display'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['display', 'display'],
#  ['social', 'referral'],
#  ['display', 'social'],
#  ['referral', 'referral', 'email'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['display', 'referral', 'social'],
#  ['referral', 'display', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'email', 'social'],
#  ['social', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['display', 'referral', 'social'],
#  ['social'],
#  ['social', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social', 'social'],
#  ['display', 'email', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral'],
#  ['social', 'display', 'referral'],
#  ['referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'social'],
#  ['referral', 'social', 'social'],
#  ['social', 'referral', 'referral', 'paid_search'],
#  ['social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['social', 'display', 'email'],
#  ['social'],
#  ['social', 'email', 'referral'],
#  ['display', 'referral', 'referral', 'social'],
#  ['email', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['social', 'direct', 'referral', 'display'],
#  ['display', 'referral', 'referral', 'email', 'social'],
#  ['referral', 'social'],
#  ['social', 'email', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'social', 'referral', 'referral', 'display'],
#  ['social', 'referral', 'social'],
#  ['referral'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social'],
#  ['referral', 'display', 'social', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'email'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral'],
#  ['email', 'social'],
#  ['referral', 'referral', 'social'],
#  ['paid_search', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'display'],
#  ['social'],
#  ['social', 'referral', 'email', 'referral', 'referral'],
#  ['social', 'paid_search'],
#  ['social', 'display', 'email'],
#  ['social', 'email', 'display'],
#  ['referral', 'display', 'email', 'social'],
#  ['social'],
#  ['display'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'social'],
#  ['email', 'social', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'referral'],
#  ['social', 'referral', 'social', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral'],
#  ['referral', 'referral'],
#  ['email', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral', 'referral'],
#  ['social', 'paid_search', 'referral'],
#  ['social', 'referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['social', 'referral'],
#  ['paid_search', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'social', 'email', 'paid_search', 'social'],
#  ['referral', 'social', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['social'],
#  ['display', 'social'],
#  ['social', 'social', 'referral'],
#  ['display', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social'],
#  ['social', 'email', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['social'],
#  ['social', 'referral', 'display'],
#  ['display', 'referral', 'social'],
#  ['social'],
#  ['paid_search', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral', 'social'],
#  ['social', 'paid_search'],
#  ['social', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['display', 'referral', 'referral', 'social'],
#  ['social', 'display', 'referral', 'referral'],
#  ['referral', 'social'],
#  ['paid_search', 'paid_search', 'referral', 'referral', 'social'],
#  ['social', 'email', 'display'],
#  ['email', 'referral'],
#  ['social', 'social', 'referral'],
#  ['social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'organic_search', 'referral', 'social'],
#  ['display', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'display', 'email', 'social'],
#  ['social', 'display', 'referral', 'referral'],
#  ['referral', 'social', 'display', 'referral', 'social'],
#  ['social', 'referral', 'display', 'referral'],
#  ['referral', 'referral', 'referral'],
#  ['display', 'referral', 'display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'referral', 'display', 'social'],
#  ['social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'social'],
#  ['social'],
#  ['social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral'],
#  ['referral', 'referral', 'referral', 'referral'],
#  ['display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'email', 'email', 'display', 'social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', 'display', 'display', 'display', 'social'],
#  ['referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['organic_search', 'referral', 'social'],
#  ['social'],
#  ['referral', 'display', 'referral', 'social'],
#  ['social', 'social'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'paid_search', 'social'],
#  ['social', 'referral', 'display'],
#  ['referral', 'referral', 'referral', 'referral', 'social'],
#  ['referral', 'social', 'social'],
#  ['social'],
#  ['referral', 'referral', 'social', 'social'],
#  ['social'],
#  ['referral', 'paid_search', 'referral', 'social'],
#  ['social'],
#  ['referral', 'display', 'social'],
#  ['social', 'referral'],
#  ['social', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['display', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'social', 'referral'],
#  ['social'],
#  ['referral', 'display', 'social'],
#  ['social', 'social', 'social'],
#  ['display', 'social'],
#  ['email', 'referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'paid_search', 'social'],
#  ['social', 'email'],
#  ['social'],
#  ['social', 'display', 'social'],
#  ['social', 'referral', 'referral', 'social'],
#  ['referral', 'referral'],
#  ['referral', 'referral'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'social', 'email', 'display'],
#  ['display', 'referral', 'display'],
#  ['referral', 'referral', 'social', 'social'],
#  ['social', 'social', 'social'],
#  ['social', 'display'],
#  ['referral', 'social'],
#  ['social', 'referral'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['display', 'social', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['paid_search', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'referral'],
#  ['referral', 'referral'],
#  ['email', 'paid_search', 'display', 'social'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'paid_search', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'social'],
#  ['referral', 'social'],
#  ['social'],
#  ['referral', 'referral', 'display', 'social', 'social'],
#  ['display', 'display'],
#  ['referral', 'referral', 'referral', 'social'],
#  ['referral', 'referral', 'social'],
#  ['referral', 'referral', 'social', 'social'],
#  ['referral', 'referral', 'social'],
#  ['social', 'referral', 'referral', 'display'],
#  ['social'],
#  ['social', 'referral', 'referral'],
#  ['referral', 'referral'],
#  ['referral', 'social'],
#  ...]

# %%
counts = dict()



for i in range(len(touch_list_convert3)):
    if len(touch_list_convert3[i]) == 2:
        for j in range(len(touch_list_convert3[i])):
            counts[touch_list_convert3[i][j]] = counts.get(touch_list_convert3[i][j],0)+0.5
    elif len(touch_list_convert3[i]) == 3:
        for j in range(len(touch_list_convert3[i])):
            counts[touch_list_convert3[i][j]] = counts.get(touch_list_convert3[i][j],0)+ 1/3
    elif len(touch_list_convert3[i]) == 4:
        for j in range(len(touch_list_convert3[i])):
            counts[touch_list_convert3[i][j]] = counts.get(touch_list_convert3[i][j],0)+ 1/4
    elif len(touch_list_convert3[i]) == 5:
        for j in range(len(touch_list_convert3[i])):
            counts[touch_list_convert3[i][j]] = counts.get(touch_list_convert3[i][j],0)+ 1/5
    else:
        for j in range(len(touch_list_convert3[i])):
            counts[touch_list_convert3[i][j]] = counts.get(touch_list_convert3[i][j],0)+ 1

counts
# Out:
# {'referral': 3290.0500000000798,
#  'email': 581.449999999998,
#  'social': 995.2333333333551,
#  'display': 846.1166666666815,
#  'paid_search': 338.99999999999864,
#  'direct': 3.4166666666666665,
#  'organic_search': 7.7333333333333325}

# %%
convert_tier3 = pd.DataFrame(list(counts.items()),columns = ['channel','converts'])
convert_tier3
# Out:
#           channel     converts
# 0        referral  3290.050000
# 1           email   581.450000
# 2          social   995.233333
# 3         display   846.116667
# 4     paid_search   339.000000
# 5          direct     3.416667
# 6  organic_search     7.733333

# %%
linear_model_cac1 = pd.merge(convert_tier1, tier1_spend, how='inner', right_on=['channel'],left_on=['channel'])
linear_model_cac2 = pd.merge(convert_tier2, tier2_spend, how='inner', right_on=['channel'],left_on=['channel'])
linear_model_cac3 = pd.merge(convert_tier3, tier3_spend, how='inner', right_on=['channel'],left_on=['channel'])
print(linear_model_cac1)
print(linear_model_cac2)
print(linear_model_cac3)
# Out:
#           channel     converts   spend
# 0        referral  1517.100000  1000.0
# 1           email   251.133333  1000.0
# 2         display   439.266667  1000.0
# 3          social   484.583333  1000.0
# 4     paid_search   128.050000  1000.0
# 5          direct     1.916667     0.0
# 6  organic_search     1.950000     0.0
#           channel     converts   spend
# 0         display   724.083333  2000.0
# 1        referral  2656.683333  2000.0
# 2           email   442.516667  2000.0
# 3          social   822.366667  2000.0
# 4     paid_search   237.816667  2000.0
# 5  organic_search     6.466667     0.0
# 6          direct     2.066667     0.0
#           channel     converts   spend
# 0        referral  3290.050000  3000.0
# 1           email   581.450000  3000.0
# 2          social   995.233333  3000.0
# 3         display   846.116667  3000.0
# 4     paid_search   339.000000  3000.0
# 5          direct     3.416667     0.0
# 6  organic_search     7.733333     0.0

# %%
linear_model_cac1['cac'] = linear_model_cac1['spend']/linear_model_cac1['converts']
linear_model_cac1
# Out:
#           channel     converts   spend       cac
# 0        referral  1517.100000  1000.0  0.659152
# 1           email   251.133333  1000.0  3.981949
# 2         display   439.266667  1000.0  2.276521
# 3          social   484.583333  1000.0  2.063629
# 4     paid_search   128.050000  1000.0  7.809449
# 5          direct     1.916667     0.0  0.000000
# 6  organic_search     1.950000     0.0  0.000000

# %%
linear_model_cac2['cac'] = linear_model_cac2['spend']/linear_model_cac2['converts']
linear_model_cac2
# Out:
#           channel     converts   spend       cac
# 0         display   724.083333  2000.0  2.762113
# 1        referral  2656.683333  2000.0  0.752818
# 2           email   442.516667  2000.0  4.519604
# 3          social   822.366667  2000.0  2.432005
# 4     paid_search   237.816667  2000.0  8.409840
# 5  organic_search     6.466667     0.0  0.000000
# 6          direct     2.066667     0.0  0.000000

# %%
linear_model_cac3['cac'] = linear_model_cac3['spend']/linear_model_cac3['converts']
linear_model_cac3
# Out:
#           channel     converts   spend       cac
# 0        referral  3290.050000  3000.0  0.911840
# 1           email   581.450000  3000.0  5.159515
# 2          social   995.233333  3000.0  3.014368
# 3         display   846.116667  3000.0  3.545610
# 4     paid_search   339.000000  3000.0  8.849558
# 5          direct     3.416667     0.0  0.000000
# 6  organic_search     7.733333     0.0  0.000000

# %%
linear_model_cac = pd.DataFrame()
linear_model_cac['channel'] = linear_model_cac1['channel']
linear_model_cac['converts'] = linear_model_cac1['converts'] + linear_model_cac2['converts'] + linear_model_cac3['converts']
linear_model_cac['spend'] = linear_model_cac1['spend'] + linear_model_cac2['spend'] + linear_model_cac3['spend']
linear_model_cac
# Out:
#           channel     converts   spend
# 0        referral  5531.233333  6000.0
# 1           email  3489.266667  6000.0
# 2         display  1877.016667  6000.0
# 3          social  2153.066667  6000.0
# 4     paid_search   704.866667  6000.0
# 5          direct    11.800000     0.0
# 6  organic_search    11.750000     0.0

# %%
linear_model_cac['cac'] = linear_model_cac['spend']/linear_model_cac['converts']
linear_model_cac
# Out:
#           channel     converts   spend       cac
# 0        referral  5531.233333  6000.0  1.084749
# 1           email  3489.266667  6000.0  1.719559
# 2         display  1877.016667  6000.0  3.196562
# 3          social  2153.066667  6000.0  2.786723
# 4     paid_search   704.866667  6000.0  8.512248
# 5          direct    11.800000     0.0  0.000000
# 6  organic_search    11.750000     0.0  0.000000
